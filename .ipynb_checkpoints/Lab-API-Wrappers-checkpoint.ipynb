# %% [markdown]
# #### Authentification

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
#sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id='<your client id here>',
#                                                          client_secret='<your client secret here>'))

# %%
secrets_file = open("secrets.txt","r")

# %%
string = secrets_file.read()

# %%
#string

# %%
#string.split('\n')

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %% [markdown]
# #### Authentification

# %%
#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
#1hMzceeWw7QiI6vaBkcEJO

# %% [markdown]
# # Handling large playlists - 10000 Songs

# %%
playlist = sp.user_playlist_tracks("spotify", "1hMzceeWw7QiI6vaBkcEJO")

# %%
playlist["total"]
# Out:
# 10000

# %%
len(playlist["items"])
# Out:
# 100

# %% [markdown]
# Function to extract all songs from a playlist

# %%
playlist['next']
# Out:
# 'https://api.spotify.com/v1/playlists/1hMzceeWw7QiI6vaBkcEJO/tracks?offset=100&limit=100&additional_types=track'

# %%
#sp.next(playlist)

# %%
from random import randint
from time import sleep

def get_playlist_tracks(playlist_id):
    results = sp.user_playlist_tracks("spotify",playlist_id)
    tracks = results['items']
    while results['next']!=None:
        results = sp.next(results)
        tracks = tracks + results['items']
        sleep(randint(1,3))
    return tracks

# %%
# this will take some seconds to run

all_tracks = get_playlist_tracks("1hMzceeWw7QiI6vaBkcEJO")
len(all_tracks)
# Out:
# 10000

# %% [markdown]
# # Audio features

# %%
# here we look only at the first page
playlist = sp.user_playlist_tracks("spotify", "1hMzceeWw7QiI6vaBkcEJO")

# %%
playlist["items"][12]["track"]["name"]
# Out:
# 'Somebody to Love Me'

# %%
playlist["items"][78]["track"]["name"]
# Out:
# 'Red Eyes'

# %%
# get the uri of a single song:
song_uri = playlist["items"][12]["track"]["uri"]
song_uri
# Out:
# 'spotify:track:2Tky1eOpdLXo8yYawnTMcj'

# %%
# get the audio features for that song
sp.audio_features(song_uri)
# Out:
# [{'danceability': 0.694,
#   'energy': 0.853,
#   'key': 6,
#   'loudness': -4.755,
#   'mode': 0,
#   'speechiness': 0.0415,
#   'acousticness': 0.107,
#   'instrumentalness': 1.63e-06,
#   'liveness': 0.225,
#   'valence': 0.566,
#   'tempo': 117.896,
#   'type': 'audio_features',
#   'id': '2Tky1eOpdLXo8yYawnTMcj',
#   'uri': 'spotify:track:2Tky1eOpdLXo8yYawnTMcj',
#   'track_href': 'https://api.spotify.com/v1/tracks/2Tky1eOpdLXo8yYawnTMcj',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Tky1eOpdLXo8yYawnTMcj',
#   'duration_ms': 297933,
#   'time_signature': 4}]

# %%
# get the uri of a single song:
song_uri = playlist["items"][78]["track"]["uri"]

# %%
# get the audio features for that song
sp.audio_features(song_uri)
# Out:
# [{'danceability': 0.464,
#   'energy': 0.815,
#   'key': 10,
#   'loudness': -6.371,
#   'mode': 1,
#   'speechiness': 0.0368,
#   'acousticness': 0.00871,
#   'instrumentalness': 0.201,
#   'liveness': 0.162,
#   'valence': 0.467,
#   'tempo': 161.845,
#   'type': 'audio_features',
#   'id': '71jGGLe5VtEHjIk5dU2W3S',
#   'uri': 'spotify:track:71jGGLe5VtEHjIk5dU2W3S',
#   'track_href': 'https://api.spotify.com/v1/tracks/71jGGLe5VtEHjIk5dU2W3S',
#   'analysis_url': 'https://api.spotify.com/v1/audio-analysis/71jGGLe5VtEHjIk5dU2W3S',
#   'duration_ms': 298920,
#   'time_signature': 4}]

# %% [markdown]
# # Creating the DataFrame

# %%
artist = []
uri = []
song_title= []

for i in range(len(all_tracks)):
    artist.append (all_tracks[i]["track"]["artists"][0]["name"])
    uri.append (all_tracks[i]["track"]["uri"])
    song_title.append (all_tracks[i]["track"]["name"])

# %%
artist
# Out:
# ['MassiveMusic',
#  'Hoosky',
#  'The Rolling Stones',
#  'Jane B',
#  'Domo Genesis',
#  'Tune-Yards',
#  'Bob Marley & The Wailers',
#  'T. Rex',
#  'The Dramatics',
#  'Erykah Badu',
#  'Blondie',
#  'Grizzly Bear',
#  'Mark Ronson',
#  "Edgar de l'Est",
#  'Merry Clayton',
#  'Tim Knol',
#  'Amy Winehouse',
#  'Robert Johnson',
#  'Darlyn',
#  'Eskorzo Afrobeat Experience',
#  'Israel Vibration',
#  'Britta Persson',
#  'The Derek Trucks Band',
#  "D'Angelo",
#  'Clara Nunes',
#  'Johnny Cash',
#  'RJD2',
#  'AlunaGeorge',
#  'Fink',
#  'Ryan Montbleau',
#  'The Whitest Boy Alive',
#  'Major Lazer',
#  'Emilíana Torrini',
#  'Smokey Robinson & The Miracles',
#  'Beans & Fatback',
#  'Devendra Banhart',
#  'Dr. John',
#  'Peter Bjorn and John',
#  'Hot Chip',
#  'Pretty Lights',
#  'Johnny Cash',
#  'YACHT',
#  'Susan Tedeschi',
#  'Sly Stone',
#  'Fabiana Dammers',
#  'Nina Simone',
#  'Jenny Owen Youngs',
#  'Shivaree',
#  'Rory Gallagher',
#  'Eugene McGuinness',
#  'Chico Mann',
#  'Bob Moses',
#  'Go Back To The Zoo',
#  'Monsters Of Folk',
#  'Lefties Soul Connection',
#  'Wyclef Jean',
#  'Cloud Nothings',
#  'The Mary Onettes',
#  'Amy Winehouse',
#  'Chinese Man',
#  'Joggo',
#  'Bran Van 3000',
#  'Richie Spice',
#  'Chinese Man',
#  'Al Green',
#  'Kern Koppen',
#  'The Specials',
#  'Urban Heroes',
#  'The Treble Spankers',
#  'Cass McCombs',
#  'Jimi Jules',
#  'Prace',
#  'James Taylor',
#  'Tom Misch',
#  'Eels',
#  'Amos Lee',
#  'Kevin Morby',
#  'The Specials',
#  'The War On Drugs',
#  'G. Love & Special Sauce',
#  'Jim Morey',
#  'MNDR',
#  'Selah Sue',
#  'Robin Thicke',
#  'Crookers',
#  'Razika',
#  "Mother's Finest",
#  'Wiz Khalifa',
#  'Toots & The Maytals',
#  '3 Balearos',
#  'Just Jack',
#  'Cody Chesnutt',
#  'Vanessa Da Mata',
#  'Françoise Hardy',
#  'Stromae',
#  'Scissor Sisters',
#  'The Orb',
#  'Wampire',
#  'Morphine',
#  'Amp Live',
#  'The Piglets',
#  'Current Swell',
#  'Chinese Man',
#  'Ry Cooder',
#  'Osborne',
#  'Jona Lewie',
#  'Johnossi',
#  'Local Natives',
#  'Ben Taylor',
#  'Carlos Puebla',
#  'Jamie Lidell',
#  'The Friends Of Distinction',
#  'The Waterboys',
#  "The Jouby's",
#  'Jurassic 5',
#  'Ane Brun',
#  'Bill Withers',
#  'John Holt',
#  'The Calimocho Club',
#  'Willis Earl Beal feat. Cat Power',
#  'The Submarines',
#  'Fergus Brown',
#  'Mayer Hawthorne',
#  'DAB',
#  'Elliott Smith',
#  'Jonathan Wilson',
#  'Joya Landis',
#  'Amy Winehouse',
#  'Pulp No Pulp',
#  'Creedence Clearwater Revival',
#  'Citizen Cope',
#  'Pat Rhoden',
#  'Schlachthofbronx',
#  'Jimmy Reed',
#  'Eels',
#  'Marty Robbins',
#  'Gregory Isaacs',
#  'Inc.',
#  'Angel Haze',
#  'Stevie Wonder',
#  'Odetta',
#  'The Waterboys',
#  'Bob Marley & The Wailers',
#  'Little Mix',
#  'Al Green',
#  'The Velvet Underground',
#  'Red Hot Chili Peppers',
#  'Air',
#  'Jamie Lidell',
#  'Gabriella Cilmi',
#  'Chico Buarque',
#  'Twiceyoung',
#  'Chromeo',
#  'Swing Republic',
#  'The Superimposers',
#  'Al Green',
#  'Bombino',
#  'The Men',
#  'Brushy One String',
#  'Little Dragon',
#  'Karen Elson',
#  'Eels',
#  'Ingrid Michaelson',
#  'Mark Ronson',
#  'Jamie Lidell',
#  'Devendra Banhart',
#  'Palio SuperSpeed Donkey',
#  'Kasabian',
#  'Johnny Nash',
#  'Feral Is Kinky',
#  'Baskerville',
#  'The Weeknd',
#  'LCD Soundsystem',
#  'Saule',
#  'J Rawls featuring Venus Malone & Wordsworth',
#  'Shout Out Louds',
#  'DJ Vadim',
#  'Yeasayer',
#  'Bob Marley & The Wailers',
#  'Blue Öyster Cult',
#  'Eric Clapton',
#  'The Nextmen',
#  'The Sonics',
#  'Selah Sue',
#  'Cheikh Lô',
#  'Nick Mulvey',
#  'We Cook With Fire',
#  'Red House Painters',
#  'Kalabrese',
#  'Guy Davis',
#  'Body Language',
#  'Delorean',
#  'San Cisco',
#  'Jagwar Ma',
#  'Nina & Frederik',
#  'Van Morrison',
#  'Ella Jenkins',
#  'Perneau',
#  'Gordon Lightfoot',
#  'Sean Bones',
#  'Gregory Isaacs',
#  'Freeform Five',
#  'Joshua Radin',
#  'Jamie Lidell',
#  'The Cat Empire',
#  'Giorgio Tuma',
#  'Morcheeba',
#  'Noir Désir',
#  'THESHINING',
#  'MY BABY',
#  'Randy Newman',
#  'KT Tunstall',
#  'Bondax',
#  'Milky Chance',
#  'Toro y Moi',
#  'Selah Sue',
#  'Donny Hathaway',
#  'Wilco',
#  'Cut Copy',
#  'Paul McCartney',
#  'Lucy Pearl',
#  'Jemini',
#  'Jake Bugg',
#  'Joe Simon',
#  'Ayọ',
#  'John Legend',
#  'Gregory Isaacs',
#  "Mungo's Hi Fi",
#  'The Rolling Stones',
#  'Rusted Root',
#  'T. Rex',
#  'The Specials',
#  'David Philips',
#  'Debruit',
#  'Ayọ',
#  'SoulChef',
#  'She & Him',
#  'Danny Brown',
#  'Eleni Mandell',
#  'Kakkmaddafakka',
#  'Mbiri Young Stars',
#  'Paqua',
#  'M.I.A.',
#  'Solange',
#  "Screamin' Jay Hawkins",
#  'Little Dragon',
#  'UB40',
#  'Dave Collins',
#  'Amos Lee',
#  'Eskorzo Afrobeat Experience',
#  'The Delines',
#  'The Whites',
#  'Lee Fields & The Expressions',
#  'The Black Seeds',
#  'Martha Reeves',
#  'Phoenix',
#  'Elli Ingram',
#  'Scram C Baby',
#  'Der Dritte Raum',
#  'Lissy Trullie',
#  'Gnonnas Pédro',
#  'Message To Bears',
#  'Ry Cooder',
#  'Johnny Cash',
#  'Aswad',
#  'Nu',
#  'OMC',
#  'Johnny Jenkins',
#  'Nick Mulvey',
#  'Stromae',
#  'Eric Clapton',
#  "Fat Freddy's Drop",
#  'The Super Orchestra',
#  'Blind Willie McTell',
#  'The Whitest Boy Alive',
#  'The Mamas & The Papas',
#  'Friendly Fires',
#  'The Treble Spankers',
#  'Sly & The Family Stone',
#  'Solange',
#  'Blair Dunlop',
#  'Don Downing',
#  'Bibi Tanga',
#  'War',
#  'Bruno Nicolai',
#  'Thomas Dolby',
#  'Toots & The Maytals',
#  'Selah Sue',
#  'Splendid',
#  'Ms. Dynamite',
#  'The Dublicators',
#  'Kayode Olajide',
#  'Slum Village',
#  'Body Language',
#  'Norman Greenbaum',
#  'Primal Scream',
#  'Bob Marley & The Wailers',
#  'Wild Belle',
#  'Little Dragon',
#  'Vacationer',
#  'TR/ST',
#  'Get Cape. Wear Cape. Fly',
#  'Tanlines',
#  'Culture',
#  'Jagwar Ma',
#  'Jonathan Wilson',
#  'David Bowie',
#  'Wyclef Jean',
#  'Rizzle Kicks',
#  'Todd Hannigan',
#  'Wooden Constructions',
#  'Althea And Donna',
#  'Vampire Weekend',
#  'Jimi Hendrix',
#  'Chicken Shack',
#  'G. Love & Special Sauce',
#  'Major Lazer',
#  'Average White Band',
#  'Talking Heads',
#  'War',
#  'Donavon Frankenreiter',
#  'OK Go',
#  'Massive Attack',
#  'Session Victim',
#  'Fatback Band',
#  'Blood Orange',
#  'Danny Michel',
#  'Fishlights',
#  'Lutan Fyah',
#  'Craig Carothers',
#  'Wild Beasts',
#  'Corinne Bailey Rae',
#  'Lee "Scratch" Perry',
#  'Bill Withers',
#  'Fatboy Slim',
#  'The Fresh & Onlys',
#  'Thao & The Get Down Stay Down',
#  'Mumford & Sons',
#  "L'Orange",
#  'Kate Nash',
#  'Sunny Levine',
#  'AM & Shawn Lee',
#  'Splendid',
#  'The Band',
#  'Scissor Sisters',
#  'Para One feat. Jaw',
#  'UB40',
#  'Los Plastics Revolution',
#  'AM & Shawn Lee',
#  'The Church',
#  'Pajaro Sunrise',
#  'October Dance',
#  'Steppenwolf',
#  'Ayọ',
#  'Balthazar',
#  'Watchhouse',
#  'Liz Green',
#  'Radiohead',
#  'Van Morrison',
#  'Janne Schra',
#  'The Drifters',
#  'John Cruz',
#  'LV',
#  'Stereo Total',
#  'Chromeo',
#  'Future',
#  "Pickin' On Series",
#  'Elliott Smith',
#  'Tim Knol',
#  'The Upsessions',
#  'Lou Bond',
#  'Rizzle Kicks',
#  'Drake',
#  'Amos Lee',
#  'Bombino',
#  'Moriarty',
#  'Tim Knol',
#  'Robin Block',
#  'MOVEMENT',
#  'Big Bill Broonzy',
#  'Fleetwood Mac',
#  'MY BABY',
#  'Big Youth',
#  'Mim Suleiman',
#  'Queen of Japan',
#  'Seinabo Sey',
#  'Vampire Weekend',
#  'Miriam Makeba',
#  'Golden Silvers',
#  'Big Bill Broonzy',
#  'Stromae',
#  'Tango Alpha Tango',
#  'yU',
#  'G. Love & Special Sauce',
#  'No Ninja Am I',
#  'Zatharanga Experience',
#  'Shuggie Otis',
#  'Sharon Van Etten',
#  'Kiki Gyan',
#  'Eric Clapton',
#  'The Slackers',
#  'Newton Faulkner',
#  'Lisa Hannigan',
#  'Ed Sheeran',
#  'Allen Stone',
#  'Lorde',
#  'Elliot Goldenthal',
#  'Mandrill',
#  'Millionyoung',
#  'Letta Mbulu',
#  'Balkan Beat Box',
#  'David Byrne',
#  'The Clash',
#  'Orchestra Baobab',
#  'Arctic Monkeys',
#  'Phoenix',
#  'The Asteroids Galaxy Tour',
#  'Bibi Tanga & The Selenites',
#  'Allah-Las',
#  'Saule',
#  'Donovan',
#  'Ry Cooder',
#  'Mandrill',
#  'Parov Stelar',
#  'Lovers',
#  'Gin Ga',
#  'The Donkeys',
#  'Schlachthofbronx',
#  'Fergus Brown',
#  "Fun Lovin' Criminals",
#  'I am Aisha',
#  'Retro Culture',
#  'Mazes',
#  'Maria Rita',
#  'I Am Kloot',
#  'Jr. Walker & The All Stars',
#  'Taj Mahal',
#  'The Upsetters',
#  'Jonathan Jeremiah',
#  'Cut Copy',
#  'Señor Coconut',
#  'Villeneuf',
#  'Javelin',
#  'Charlotte Gainsbourg',
#  'Chaka Khan',
#  'The Offspring',
#  'Them Vibes',
#  'Adriana Calcanhotto',
#  'William Onyeabor',
#  'Valerie June',
#  'Ane Brun',
#  'We Are KING',
#  'Van Morrison',
#  'Spengler',
#  'Common',
#  'FS Green',
#  'Gaby Moreno Y Su Orquesta',
#  'Sean Bones',
#  'Lou Johnson',
#  'Gwen McCrae',
#  'Finley Quaye',
#  'MGMT',
#  'The Selecter',
#  'The Meters',
#  'Max Sedgley',
#  'Joe Higgs',
#  'The Pioneers',
#  'Ben Pearce',
#  'Bob Marley & The Wailers',
#  'The Gladiators',
#  'The Black Seeds',
#  'Tim Knol',
#  'Etta James',
#  'Simon & Garfunkel',
#  'Dazzled Kid',
#  'Electronic',
#  'The Wailers',
#  'Bobby Byrd',
#  'C2C',
#  'Selah Sue',
#  'Muddy Waters',
#  'Jack and the Weatherman',
#  'Maria Rita',
#  'The Hics',
#  'Chico Buarque',
#  'Michael Franti',
#  'Cornershop',
#  'Nara Leão',
#  'Future Islands',
#  'Anita Carter',
#  'Valerie June',
#  'J.J. Cale',
#  'John Wizards',
#  'Tired Pony',
#  'Chico Buarque',
#  'Meta And The Cornerstones',
#  'M.I.A.',
#  'Gwen McCrae',
#  'Alabama Shakes',
#  'The Opposites',
#  'J.J. Cale',
#  'Joe South',
#  'Bright Eyes',
#  'The Orb',
#  'Typesun',
#  'Hollywood, Mon Amour',
#  'The Budos Band',
#  'Paolo Nutini',
#  'Bombay Bicycle Club',
#  'Zachary Cale',
#  'The Drums',
#  'BANKS',
#  'Delegation',
#  "Alessi's Ark",
#  'Bobby Hebb',
#  'Ben Sollee',
#  'Aretha Franklin',
#  'Fiona Apple',
#  'The Beautiful Girls',
#  'Al Green',
#  'Japan',
#  'Robert Johnson',
#  'Edward Sharpe & The Magnetic Zeros',
#  'Barth',
#  'Eddie Harris',
#  'Hirth Martinez',
#  'Gorillaz',
#  'Justin Timberlake',
#  'The Pointer Sisters',
#  'The Ting Tings',
#  'Awanto 3',
#  'Eek-A-Mouse',
#  'Michael Kiwanuka',
#  'Emilíana Torrini',
#  'The Black Seeds',
#  'The Byrds',
#  'Big Joe Williams',
#  'Black Joe Lewis & The Honeybears',
#  "Ben L'Oncle Soul",
#  'Arno',
#  'The Meters',
#  'David Bromberg',
#  'Spirit',
#  'De Staat',
#  'Quiller',
#  'Jake Bugg',
#  'Faberyayo',
#  'Kultiration',
#  'Kris Berry',
#  'Dan Lyth',
#  'Erma Franklin',
#  'Disturbing Tha Peace',
#  'Moderat',
#  'The Nextmen',
#  'Mason Jennings',
#  'Fela Kuti',
#  'Criolo',
#  'Elmore James',
#  'John Holt',
#  'Efterklang',
#  'I Monster',
#  'D.I.D',
#  'Seu Jorge',
#  'Tim Maia',
#  'Donovan',
#  'Maurits Westerik',
#  'Robert Palmer',
#  "Chef'Special",
#  'Brett Dennen',
#  'San Cisco',
#  'Wolf in Loveland',
#  'Miike Snow',
#  'Francisco The Man',
#  'Emika',
#  'Danger Mouse',
#  'June Lodge',
#  'Norah Jones',
#  'Goldroom',
#  'Rory Gallagher',
#  'Poolside',
#  'UB40',
#  'Kalabrese',
#  'Kings of Leon',
#  'Paloma Faith',
#  'Tony Tribe',
#  'Digitalism',
#  'Robert Johnson',
#  'Ladi6',
#  'Clubfeet',
#  'Mayer Hawthorne',
#  'The Meters',
#  'Yellus',
#  'Frankie Valli & The Four Seasons',
#  'Crosby, Stills, Nash & Young',
#  'Ed Sheeran',
#  'Ernie K-Doe',
#  'Neneh Cherry',
#  'Ciara',
#  'Steve Miller Band',
#  'Splendid',
#  'Vanessa Da Mata',
#  'Tuka',
#  'Hooded Fang',
#  'Duffy',
#  'Champion Jack Dupree',
#  'Staygold',
#  'Fischer-Z',
#  'Dazzled Kid',
#  'Timber Timbre',
#  'Brazilian Girls',
#  'Disclosure',
#  'FTSE',
#  'The Egyptian Lover',
#  'Retro Stefson',
#  'Bodies of Work',
#  'Bob Dylan',
#  'Grandaddy',
#  'Donavon Frankenreiter',
#  'The Modern Lovers',
#  "Fat Freddy's Drop",
#  'Little Legend',
#  'The Art Of Noise',
#  'Clint Eastwood & General Saint',
#  'Oliver',
#  'Richie Spice',
#  'Klak Tik',
#  'James Taylor',
#  'The Cat Empire',
#  'Katy B',
#  'Of Monsters and Men',
#  'Van Morrison',
#  'Jenny O.',
#  'Passion Pit',
#  'Christine Perfect',
#  'Eliza Doolittle',
#  'The Connells',
#  'Natiruts',
#  'John Mayer',
#  'Ernest Ranglin',
#  'Stevie Wonder',
#  'James Brown',
#  'J.B. Hutto and His Hawks',
#  'Amy Ray',
#  'Tim Maia',
#  "Fat Freddy's Drop",
#  'Born Ruffians',
#  'The Treble Spankers',
#  'Classified',
#  "Fat Freddy's Drop",
#  'The Emotions',
#  'Gregory Alan Isakov',
#  'Freddie Joachim',
#  'Daft Punk',
#  'Tinariwen',
#  'Chromeo',
#  'Prace',
#  'Kelly Joe Phelps',
#  'Harry Chapin',
#  'Agnes Obel',
#  'Vandaveer',
#  'Glen Faria',
#  'The Budos Band',
#  'Dennis Brown',
#  'Hot Chip',
#  'Old',
#  'Gaby Moreno Y Su Orquesta',
#  'Ralph McTell',
#  'Rare Silk',
#  'Lil Silva',
#  'David Philips',
#  'Roosevelt Sykes',
#  'Elis Regina',
#  'Son House',
#  'Amy Ray',
#  'Dub Pistols',
#  'Boozoo Bajou',
#  'Mose Allison',
#  'Stornoway',
#  'Phoenix',
#  'Amy Winehouse',
#  'Lizz Wright',
#  'The National',
#  'Joe Jackson',
#  'Carrie Riley & The Fascinations',
#  'Robert Palmer',
#  'A K U A',
#  'The Avalanches',
#  'Max & Simon',
#  'Woolfy',
#  'Leagues',
#  'Camille',
#  'Lost Midas',
#  'The Meters',
#  'Talking Heads',
#  'La Roux',
#  'Mike Posner',
#  'Jagwar Ma',
#  'Korby Lenker',
#  'Kings of Convenience',
#  'Blood Orange',
#  'Them Vibes',
#  'John Mayer',
#  'Fujiya & Miyagi',
#  'Mozes and the Firstborn',
#  'Jake Bugg',
#  'Avalanche City',
#  'Richard Hawley',
#  'Marvin Gaye',
#  'The Asteroids Galaxy Tour',
#  'Johnny Cash',
#  'Gorillaz',
#  'Ayọ',
#  'Dubmatix',
#  'Bronze Whale',
#  'Ray Kane',
#  'Splendid',
#  'GIVERS',
#  'Junior Boys',
#  'Andrew Collberg',
#  'Dave Aju',
#  'Devendra Banhart',
#  'Johnny Cash',
#  'Milky Chance',
#  'M.I.A.',
#  'The Decemberists',
#  'Friendly Fires',
#  'Toro y Moi',
#  'Davy Graham',
#  'Jonathan Wilson',
#  'Wilbert Harrison',
#  'Cloud Nothings',
#  'Big Mama Thornton',
#  'John Mayer',
#  'The Specials Featuring Rico',
#  'Jorge Ben Jor',
#  'Beach Fossils',
#  'Crystal Fighters',
#  'De Staat',
#  'CSS',
#  'Sly & The Family Stone',
#  'Basement Jaxx',
#  'Westbound Train',
#  'Balkan Beat Box',
#  'Elbow',
#  'Kishi Bashi',
#  'Vladimir and his orchestra',
#  'The Raconteurs',
#  'Natty',
#  'The Limp Twins',
#  'Wyclef Jean',
#  'Mr Hudson',
#  'Lucy Pearl',
#  'Massive Attack',
#  'The Temper Trap',
#  'J.J. Cale',
#  'The Upsessions',
#  'Holy Ghost!',
#  'Marvin Gaye',
#  'Living Colour',
#  'Beck',
#  'Lola Kite',
#  'Ginger Ninja',
#  'Classixx',
#  'Crosby, Stills, Nash & Young',
#  'Galliano',
#  'The Phoenix Foundation',
#  'Eugene McGuinness',
#  'David Essex',
#  'Gregory Isaacs',
#  'Alamo Race Track',
#  'Yeah Yeah Yeahs',
#  'David Philips',
#  'Air',
#  'Minnie Riperton',
#  'The Weeknd',
#  'The Dynamics',
#  'Woolfy vs Projections',
#  'Dr. John',
#  'Sturgill Simpson',
#  'Chico Buarque',
#  'Ofo The Black Company',
#  'Plan B',
#  'Marcia Griffiths',
#  'Smash TV',
#  'Vanessa Paradis',
#  'Santoré',
#  'AM & Shawn Lee',
#  'Mile Me Deaf',
#  'Jagwar Ma',
#  'Prattle On, Rick.',
#  'Lady Linn',
#  'Junior Parker',
#  'Janne Schra',
#  'Irma Thomas',
#  'Cheryl Lynn',
#  'Frank Wiedemann',
#  'Will And The People',
#  'Sin Cos Tan',
#  'Keren Ann',
#  '17 Hippies',
#  'John Talabot',
#  'Jon Mcxro',
#  'The Roots',
#  'Beck',
#  'Belleruche',
#  'Gil Scott-Heron',
#  "Fat Freddy's Drop",
#  'TV On The Radio',
#  'Lenine',
#  'Tim Knol',
#  'Dub Syndicate',
#  'Jesse Woods',
#  'Bonobo',
#  'The Weeknd',
#  'James Hunter',
#  'Quentin Quatro',
#  'Eric Clapton',
#  'The Slackers',
#  'The Dynamics',
#  'Alex Winston',
#  'The Black Keys',
#  'Woodward',
#  'Dur-Dur Band',
#  'G. Love & Special Sauce',
#  'Claptone',
#  'Grateful Dead',
#  'DJ Shadow',
#  'Ezéchiel Pailhès',
#  'The Band',
#  'Arcade Fire',
#  'Spoon',
#  'Muddy Waters',
#  'Daryll-Ann',
#  'Moodymann',
#  'Angus & Julia Stone',
#  'AWKWARD i',
#  'Moonlight Mask',
#  'Wyclef Jean',
#  'Bing Ji Ling',
#  'The Clown',
#  'Matias Aguayo',
#  'R.E.M.',
#  'Paul Simon',
#  'Yung Life',
#  'G. Love & Special Sauce',
#  'Galt MacDermot',
#  'Charles Wright',
#  'Thao & The Get Down Stay Down',
#  'Cherub',
#  'Dustin Tebbutt',
#  'Doves',
#  'Architecture In Helsinki',
#  'Moodymann',
#  'Amy Winehouse',
#  'Jane Birkin',
#  'Menahan Street Band',
#  'Shawn Anthony',
#  'Maza Blaska',
#  'Jimmy Cliff',
#  'Van Morrison',
#  'Pieter Embrechts',
#  'Julien Dyne',
#  'Miike Snow',
#  'Classixx',
#  'Jack Johnson',
#  'Troumaca',
#  'Vampire Weekend',
#  'Gaby Moreno',
#  'Saule',
#  "Mungo's Hi Fi",
#  'The Funkees',
#  'I am Aisha',
#  'Electric Guest',
#  'Tuesday Born',
#  'Johnny Cash',
#  'Lloyd Charmers',
#  'New Navy',
#  'Mary Gauthier',
#  'Black Mamba',
#  'Matthew Barber',
#  'The Selecter',
#  'Laid Back',
#  'Moss',
#  'Watchhouse',
#  'Paul Simon',
#  'Andreya Triana',
#  'The Black Seeds',
#  'Donovan',
#  'Gin Wigmore',
#  'Bombay Bicycle Club',
#  'Paulusma',
#  'David Bromberg',
#  'Sam Sparro',
#  'SpectraSoul feat. Echo Park',
#  'Rilan & The Bombardiers',
#  'Taj Mahal',
#  'J.J. Cale',
#  'Jeremih',
#  "Chef'Special",
#  'Blind Boy Fuller',
#  'Tunng',
#  'Margot',
#  'Jungle',
#  'Balthazar',
#  'Apes in the Orange Grove',
#  'Idris Muhammad',
#  'The Ting Tings',
#  'The Phoenix Foundation',
#  'Amy Winehouse',
#  'Hollywood, Mon Amour',
#  'Empire of the Sun',
#  'Los Cafres',
#  'Tosca',
#  'Martinho Da Silva',
#  'M.I.A.',
#  'Gin Ga',
#  'Angus & Julia Stone',
#  'Bob Dylan',
#  'Quincy Jones',
#  'Brazilian Girls',
#  'Oh Blimey',
#  'Fleetwood Mac',
#  'Sébastien Tellier',
#  'Joe Torres',
#  "Chef'Special",
#  'Mariah Carey',
#  'Eddy Grant',
#  'James Hunter',
#  'Maison du Malheur',
#  'Chancha Via Circuito',
#  'Arctic Monkeys',
#  'Willis Earl Beal',
#  'Rory Gallagher',
#  'Gardens & Villa',
#  'The Bees',
#  'Quadron',
#  'Bobbie Gentry',
#  'Eric Lau',
#  'C.K.Mann',
#  'Lykke Li',
#  'Benjamin Biolay',
#  'Bobby Womack',
#  'Eva Ayllón',
#  'Fatback Band',
#  'T-Bone Walker',
#  'CSS',
#  'Peter Broderick',
#  'Mable John',
#  'Van Morrison',
#  'Michael Mayer',
#  'Mississippi Joe Callicott',
#  'The Specials',
#  'Yoav',
#  'Spoon',
#  'Amongst Giants',
#  'Champion Jack Dupree',
#  'Nara Leão',
#  'Josh Rouse',
#  'Scissor Sisters',
#  'Finley Quaye',
#  'Junior Boys',
#  'Laura Gibson',
#  'SKIP&DIE',
#  'Jesse Woods',
#  'Berry',
#  'Eric Clapton',
#  'Tensnake',
#  'Bob Dylan',
#  'The Asteroids Galaxy Tour',
#  'Pajaro Sunrise',
#  'Splendid',
#  'Chlöe Howl',
#  'Stromae',
#  'Komiko',
#  'The Dead Brothers',
#  'Otis Redding',
#  'X-O-Dus',
#  'Steve Miller Band',
#  'Angel Olsen',
#  'Michael Franti',
#  'Grateful Dead',
#  'Outkast',
#  'Generationals',
#  'Joaquín Díaz',
#  'Ray Charles',
#  'Edu Lobo',
#  'Guy Clark',
#  'Easy Star All-Stars',
#  'Jungle',
#  'Asaf Avidan & the Mojos',
#  'Spanky Wilson',
#  'Peter Cetera',
#  'Anita Carter',
#  'Inc.',
#  'Michael Kiwanuka',
#  'Nada Surf',
#  'Solomon Burke',
#  'Sofie Winterson',
#  'Choir Of Young Believers',
#  'The Beach Boys',
#  ...]

# %%
import pandas as pd
playlist_df = pd.DataFrame({"name":song_title, "artist":artist, "uri":uri})

# %%
playlist_df
# Out:
#                                            name              artist  \
# 0          This Magic Moment - Crisp.nl Version        MassiveMusic
# 1                                         00h00              Hoosky
# 2                                Under My Thumb  The Rolling Stones
# 3                                    Conquer Me              Jane B
# 4                 Dapper (feat. Anderson .Paak)        Domo Genesis
# ...                                         ...                 ...
# 9995                                      Lijay      Mulatu Astatke
# 9996  Pretty Nice Life (feat. Tiken Jah Fakoly)            M.I.L.K.
# 9997             Take It Slow - Mousse T. Remix        Boozoo Bajou
# 9998                         Birds of a Feather               Mocky
# 9999                             Freeway (2006)         Earl Elliot
#
#                                        uri
# 0     spotify:track:6uDlwsguxFDgbakvPyhChp
# 1     spotify:track:00LvjMnpznr4MZFSA8x9sA
# 2     spotify:track:3E8gEvhLia6w9lQv3hfxzM
# 3     spotify:track:2jjPlj6KFzCffJ7KVQMwHX
# 4     spotify:track:3seHx466iTcUmWE9dOVB3v
# ...                                    ...
# 9995  spotify:track:57BxU4uqdbl6TITWtnQDMw
# 9996  spotify:track:7lL6ND4Jj1tWpoDFaJoxtS
# 9997  spotify:track:1PNaGC2ihDmVCldSce119E
# 9998  spotify:track:2887tlqmjY4WcyQ3Dy6dZy
# 9999  spotify:track:5xPYheD4STE2K5o6ff9WJK
#
# [10000 rows x 3 columns]

# %%
audio_features = []


for i in playlist_df["uri"]:
    audio_features.append (sp.audio_features(i))

# %%
audio_features
# Out:
# [[{'danceability': 0.823,
#    'energy': 0.671,
#    'key': 11,
#    'loudness': -6.437,
#    'mode': 1,
#    'speechiness': 0.0592,
#    'acousticness': 0.551,
#    'instrumentalness': 0.00144,
#    'liveness': 0.354,
#    'valence': 0.662,
#    'tempo': 125.052,
#    'type': 'audio_features',
#    'id': '6uDlwsguxFDgbakvPyhChp',
#    'uri': 'spotify:track:6uDlwsguxFDgbakvPyhChp',
#    'track_href': 'https://api.spotify.com/v1/tracks/6uDlwsguxFDgbakvPyhChp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6uDlwsguxFDgbakvPyhChp',
#    'duration_ms': 188697,
#    'time_signature': 4}],
#  [{'danceability': 0.375,
#    'energy': 0.606,
#    'key': 4,
#    'loudness': -9.383,
#    'mode': 0,
#    'speechiness': 0.197,
#    'acousticness': 0.339,
#    'instrumentalness': 0.000924,
#    'liveness': 0.424,
#    'valence': 0.883,
#    'tempo': 91.564,
#    'type': 'audio_features',
#    'id': '00LvjMnpznr4MZFSA8x9sA',
#    'uri': 'spotify:track:00LvjMnpznr4MZFSA8x9sA',
#    'track_href': 'https://api.spotify.com/v1/tracks/00LvjMnpznr4MZFSA8x9sA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/00LvjMnpznr4MZFSA8x9sA',
#    'duration_ms': 51373,
#    'time_signature': 4}],
#  [{'danceability': 0.738,
#    'energy': 0.491,
#    'key': 6,
#    'loudness': -13.407,
#    'mode': 0,
#    'speechiness': 0.0487,
#    'acousticness': 0.298,
#    'instrumentalness': 0.218,
#    'liveness': 0.119,
#    'valence': 0.809,
#    'tempo': 126.96,
#    'type': 'audio_features',
#    'id': '3E8gEvhLia6w9lQv3hfxzM',
#    'uri': 'spotify:track:3E8gEvhLia6w9lQv3hfxzM',
#    'track_href': 'https://api.spotify.com/v1/tracks/3E8gEvhLia6w9lQv3hfxzM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3E8gEvhLia6w9lQv3hfxzM',
#    'duration_ms': 221533,
#    'time_signature': 4}],
#  [{'danceability': 0.657,
#    'energy': 0.488,
#    'key': 8,
#    'loudness': -10.416,
#    'mode': 0,
#    'speechiness': 0.0456,
#    'acousticness': 0.213,
#    'instrumentalness': 0.0942,
#    'liveness': 0.36,
#    'valence': 0.662,
#    'tempo': 149.763,
#    'type': 'audio_features',
#    'id': '2jjPlj6KFzCffJ7KVQMwHX',
#    'uri': 'spotify:track:2jjPlj6KFzCffJ7KVQMwHX',
#    'track_href': 'https://api.spotify.com/v1/tracks/2jjPlj6KFzCffJ7KVQMwHX',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2jjPlj6KFzCffJ7KVQMwHX',
#    'duration_ms': 216235,
#    'time_signature': 4}],
#  [{'danceability': 0.753,
#    'energy': 0.594,
#    'key': 1,
#    'loudness': -9.486,
#    'mode': 0,
#    'speechiness': 0.0816,
#    'acousticness': 0.0711,
#    'instrumentalness': 0,
#    'liveness': 0.391,
#    'valence': 0.562,
#    'tempo': 112.568,
#    'type': 'audio_features',
#    'id': '3seHx466iTcUmWE9dOVB3v',
#    'uri': 'spotify:track:3seHx466iTcUmWE9dOVB3v',
#    'track_href': 'https://api.spotify.com/v1/tracks/3seHx466iTcUmWE9dOVB3v',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3seHx466iTcUmWE9dOVB3v',
#    'duration_ms': 193093,
#    'time_signature': 4}],
#  [{'danceability': 0.825,
#    'energy': 0.69,
#    'key': 1,
#    'loudness': -6.234,
#    'mode': 1,
#    'speechiness': 0.065,
#    'acousticness': 0.00337,
#    'instrumentalness': 0.00277,
#    'liveness': 0.367,
#    'valence': 0.589,
#    'tempo': 110.488,
#    'type': 'audio_features',
#    'id': '3pndgH9sLDTCWtCwr8LWt9',
#    'uri': 'spotify:track:3pndgH9sLDTCWtCwr8LWt9',
#    'track_href': 'https://api.spotify.com/v1/tracks/3pndgH9sLDTCWtCwr8LWt9',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3pndgH9sLDTCWtCwr8LWt9',
#    'duration_ms': 183453,
#    'time_signature': 4}],
#  [{'danceability': 0.784,
#    'energy': 0.52,
#    'key': 0,
#    'loudness': -8.27,
#    'mode': 1,
#    'speechiness': 0.227,
#    'acousticness': 0.121,
#    'instrumentalness': 0.00158,
#    'liveness': 0.146,
#    'valence': 0.854,
#    'tempo': 72.678,
#    'type': 'audio_features',
#    'id': '3PPigifoeEofIISQYbayMK',
#    'uri': 'spotify:track:3PPigifoeEofIISQYbayMK',
#    'track_href': 'https://api.spotify.com/v1/tracks/3PPigifoeEofIISQYbayMK',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PPigifoeEofIISQYbayMK',
#    'duration_ms': 134573,
#    'time_signature': 4}],
#  [{'danceability': 0.342,
#    'energy': 0.442,
#    'key': 8,
#    'loudness': -9.782,
#    'mode': 1,
#    'speechiness': 0.0346,
#    'acousticness': 0.793,
#    'instrumentalness': 0.000105,
#    'liveness': 0.0758,
#    'valence': 0.804,
#    'tempo': 147.7,
#    'type': 'audio_features',
#    'id': '3olQaoZDc2O1mFDod0evZI',
#    'uri': 'spotify:track:3olQaoZDc2O1mFDod0evZI',
#    'track_href': 'https://api.spotify.com/v1/tracks/3olQaoZDc2O1mFDod0evZI',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3olQaoZDc2O1mFDod0evZI',
#    'duration_ms': 132800,
#    'time_signature': 4}],
#  [{'danceability': 0.638,
#    'energy': 0.708,
#    'key': 6,
#    'loudness': -10.383,
#    'mode': 1,
#    'speechiness': 0.128,
#    'acousticness': 0.226,
#    'instrumentalness': 0,
#    'liveness': 0.12,
#    'valence': 0.904,
#    'tempo': 153.144,
#    'type': 'audio_features',
#    'id': '6J7uQ9vLtBqNikEhlKUOnu',
#    'uri': 'spotify:track:6J7uQ9vLtBqNikEhlKUOnu',
#    'track_href': 'https://api.spotify.com/v1/tracks/6J7uQ9vLtBqNikEhlKUOnu',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6J7uQ9vLtBqNikEhlKUOnu',
#    'duration_ms': 212840,
#    'time_signature': 4}],
#  [{'danceability': 0.72,
#    'energy': 0.272,
#    'key': 9,
#    'loudness': -12.919,
#    'mode': 0,
#    'speechiness': 0.0683,
#    'acousticness': 0.58,
#    'instrumentalness': 0,
#    'liveness': 0.145,
#    'valence': 0.661,
#    'tempo': 132.494,
#    'type': 'audio_features',
#    'id': '6uI95ERPZV6tivkNWsOKet',
#    'uri': 'spotify:track:6uI95ERPZV6tivkNWsOKet',
#    'track_href': 'https://api.spotify.com/v1/tracks/6uI95ERPZV6tivkNWsOKet',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6uI95ERPZV6tivkNWsOKet',
#    'duration_ms': 322533,
#    'time_signature': 4}],
#  [{'danceability': 0.641,
#    'energy': 0.531,
#    'key': 9,
#    'loudness': -13.691,
#    'mode': 1,
#    'speechiness': 0.0496,
#    'acousticness': 0.0256,
#    'instrumentalness': 0.000248,
#    'liveness': 0.178,
#    'valence': 0.846,
#    'tempo': 145.886,
#    'type': 'audio_features',
#    'id': '23yv078f5kc08Kj6DMpO0t',
#    'uri': 'spotify:track:23yv078f5kc08Kj6DMpO0t',
#    'track_href': 'https://api.spotify.com/v1/tracks/23yv078f5kc08Kj6DMpO0t',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/23yv078f5kc08Kj6DMpO0t',
#    'duration_ms': 185067,
#    'time_signature': 4}],
#  [{'danceability': 0.537,
#    'energy': 0.712,
#    'key': 5,
#    'loudness': -5.597,
#    'mode': 1,
#    'speechiness': 0.0286,
#    'acousticness': 0.289,
#    'instrumentalness': 0.00568,
#    'liveness': 0.08,
#    'valence': 0.704,
#    'tempo': 159.871,
#    'type': 'audio_features',
#    'id': '0iTpQYzJnYgh7kIxyq8A2O',
#    'uri': 'spotify:track:0iTpQYzJnYgh7kIxyq8A2O',
#    'track_href': 'https://api.spotify.com/v1/tracks/0iTpQYzJnYgh7kIxyq8A2O',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0iTpQYzJnYgh7kIxyq8A2O',
#    'duration_ms': 243160,
#    'time_signature': 4}],
#  [{'danceability': 0.694,
#    'energy': 0.853,
#    'key': 6,
#    'loudness': -4.755,
#    'mode': 0,
#    'speechiness': 0.0415,
#    'acousticness': 0.107,
#    'instrumentalness': 1.63e-06,
#    'liveness': 0.225,
#    'valence': 0.566,
#    'tempo': 117.896,
#    'type': 'audio_features',
#    'id': '2Tky1eOpdLXo8yYawnTMcj',
#    'uri': 'spotify:track:2Tky1eOpdLXo8yYawnTMcj',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Tky1eOpdLXo8yYawnTMcj',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Tky1eOpdLXo8yYawnTMcj',
#    'duration_ms': 297933,
#    'time_signature': 4}],
#  [{'danceability': 0.829,
#    'energy': 0.353,
#    'key': 9,
#    'loudness': -10.409,
#    'mode': 1,
#    'speechiness': 0.246,
#    'acousticness': 0.605,
#    'instrumentalness': 2.44e-05,
#    'liveness': 0.124,
#    'valence': 0.897,
#    'tempo': 134.979,
#    'type': 'audio_features',
#    'id': '0JBUms0CMKVARibROy8x7N',
#    'uri': 'spotify:track:0JBUms0CMKVARibROy8x7N',
#    'track_href': 'https://api.spotify.com/v1/tracks/0JBUms0CMKVARibROy8x7N',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JBUms0CMKVARibROy8x7N',
#    'duration_ms': 234227,
#    'time_signature': 4}],
#  [{'danceability': 0.584,
#    'energy': 0.821,
#    'key': 7,
#    'loudness': -9.016,
#    'mode': 0,
#    'speechiness': 0.0468,
#    'acousticness': 0.329,
#    'instrumentalness': 0.000282,
#    'liveness': 0.565,
#    'valence': 0.646,
#    'tempo': 117.619,
#    'type': 'audio_features',
#    'id': '318Vrl9zzFT7zT8BYKNhgP',
#    'uri': 'spotify:track:318Vrl9zzFT7zT8BYKNhgP',
#    'track_href': 'https://api.spotify.com/v1/tracks/318Vrl9zzFT7zT8BYKNhgP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/318Vrl9zzFT7zT8BYKNhgP',
#    'duration_ms': 211293,
#    'time_signature': 4}],
#  [{'danceability': 0.563,
#    'energy': 0.146,
#    'key': 3,
#    'loudness': -14.421,
#    'mode': 0,
#    'speechiness': 0.0408,
#    'acousticness': 0.894,
#    'instrumentalness': 1.6e-05,
#    'liveness': 0.111,
#    'valence': 0.268,
#    'tempo': 133.115,
#    'type': 'audio_features',
#    'id': '1jajG9Yo6m71VEpXx3uRzT',
#    'uri': 'spotify:track:1jajG9Yo6m71VEpXx3uRzT',
#    'track_href': 'https://api.spotify.com/v1/tracks/1jajG9Yo6m71VEpXx3uRzT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1jajG9Yo6m71VEpXx3uRzT',
#    'duration_ms': 233333,
#    'time_signature': 4}],
#  [{'danceability': 0.875,
#    'energy': 0.481,
#    'key': 9,
#    'loudness': -5.088,
#    'mode': 0,
#    'speechiness': 0.0451,
#    'acousticness': 0.0574,
#    'instrumentalness': 0.000453,
#    'liveness': 0.0916,
#    'valence': 0.716,
#    'tempo': 91.474,
#    'type': 'audio_features',
#    'id': '2pkKNXOwwEc8qgeQRtg6IJ',
#    'uri': 'spotify:track:2pkKNXOwwEc8qgeQRtg6IJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/2pkKNXOwwEc8qgeQRtg6IJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2pkKNXOwwEc8qgeQRtg6IJ',
#    'duration_ms': 234107,
#    'time_signature': 4}],
#  [{'danceability': 0.681,
#    'energy': 0.193,
#    'key': 2,
#    'loudness': -15.254,
#    'mode': 1,
#    'speechiness': 0.0581,
#    'acousticness': 0.982,
#    'instrumentalness': 0.00522,
#    'liveness': 0.128,
#    'valence': 0.638,
#    'tempo': 101.924,
#    'type': 'audio_features',
#    'id': '5yxmp7HffmzRsrklr8xyrV',
#    'uri': 'spotify:track:5yxmp7HffmzRsrklr8xyrV',
#    'track_href': 'https://api.spotify.com/v1/tracks/5yxmp7HffmzRsrklr8xyrV',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5yxmp7HffmzRsrklr8xyrV',
#    'duration_ms': 156240,
#    'time_signature': 4}],
#  [{'danceability': 0.513,
#    'energy': 0.083,
#    'key': 0,
#    'loudness': -13.451,
#    'mode': 1,
#    'speechiness': 0.0454,
#    'acousticness': 0.893,
#    'instrumentalness': 0,
#    'liveness': 0.115,
#    'valence': 0.28,
#    'tempo': 119.585,
#    'type': 'audio_features',
#    'id': '0zEjqBMZNkUFCDUmuYoGxO',
#    'uri': 'spotify:track:0zEjqBMZNkUFCDUmuYoGxO',
#    'track_href': 'https://api.spotify.com/v1/tracks/0zEjqBMZNkUFCDUmuYoGxO',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0zEjqBMZNkUFCDUmuYoGxO',
#    'duration_ms': 169842,
#    'time_signature': 4}],
#  [{'danceability': 0.618,
#    'energy': 0.894,
#    'key': 0,
#    'loudness': -8.703,
#    'mode': 1,
#    'speechiness': 0.0327,
#    'acousticness': 0.0536,
#    'instrumentalness': 0.577,
#    'liveness': 0.0611,
#    'valence': 0.91,
#    'tempo': 96.991,
#    'type': 'audio_features',
#    'id': '2mu6r9KaIxj2CRrIcJTm0b',
#    'uri': 'spotify:track:2mu6r9KaIxj2CRrIcJTm0b',
#    'track_href': 'https://api.spotify.com/v1/tracks/2mu6r9KaIxj2CRrIcJTm0b',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2mu6r9KaIxj2CRrIcJTm0b',
#    'duration_ms': 468143,
#    'time_signature': 4}],
#  [{'danceability': 0.885,
#    'energy': 0.482,
#    'key': 5,
#    'loudness': -11.874,
#    'mode': 0,
#    'speechiness': 0.204,
#    'acousticness': 0.0127,
#    'instrumentalness': 0,
#    'liveness': 0.0916,
#    'valence': 0.946,
#    'tempo': 137.425,
#    'type': 'audio_features',
#    'id': '6nKvpwVXvwqWHYkv8W8v5g',
#    'uri': 'spotify:track:6nKvpwVXvwqWHYkv8W8v5g',
#    'track_href': 'https://api.spotify.com/v1/tracks/6nKvpwVXvwqWHYkv8W8v5g',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6nKvpwVXvwqWHYkv8W8v5g',
#    'duration_ms': 285667,
#    'time_signature': 4}],
#  [{'danceability': 0.73,
#    'energy': 0.427,
#    'key': 6,
#    'loudness': -6.702,
#    'mode': 0,
#    'speechiness': 0.0308,
#    'acousticness': 0.285,
#    'instrumentalness': 0,
#    'liveness': 0.11,
#    'valence': 0.2,
#    'tempo': 100.16,
#    'type': 'audio_features',
#    'id': '4TFjClZKae5hkuegAzfKPC',
#    'uri': 'spotify:track:4TFjClZKae5hkuegAzfKPC',
#    'track_href': 'https://api.spotify.com/v1/tracks/4TFjClZKae5hkuegAzfKPC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4TFjClZKae5hkuegAzfKPC',
#    'duration_ms': 226554,
#    'time_signature': 4}],
#  [{'danceability': 0.445,
#    'energy': 0.544,
#    'key': 9,
#    'loudness': -10.925,
#    'mode': 1,
#    'speechiness': 0.0314,
#    'acousticness': 0.698,
#    'instrumentalness': 0.477,
#    'liveness': 0.115,
#    'valence': 0.222,
#    'tempo': 101.172,
#    'type': 'audio_features',
#    'id': '7CF9D6br57ovVM7bo6B1jB',
#    'uri': 'spotify:track:7CF9D6br57ovVM7bo6B1jB',
#    'track_href': 'https://api.spotify.com/v1/tracks/7CF9D6br57ovVM7bo6B1jB',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7CF9D6br57ovVM7bo6B1jB',
#    'duration_ms': 391987,
#    'time_signature': 4}],
#  [{'danceability': 0.786,
#    'energy': 0.753,
#    'key': 10,
#    'loudness': -9.461,
#    'mode': 0,
#    'speechiness': 0.0803,
#    'acousticness': 0.312,
#    'instrumentalness': 0.0982,
#    'liveness': 0.124,
#    'valence': 0.767,
#    'tempo': 98.936,
#    'type': 'audio_features',
#    'id': '4HUQeJ3p6NI3zIioBDvFuD',
#    'uri': 'spotify:track:4HUQeJ3p6NI3zIioBDvFuD',
#    'track_href': 'https://api.spotify.com/v1/tracks/4HUQeJ3p6NI3zIioBDvFuD',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4HUQeJ3p6NI3zIioBDvFuD',
#    'duration_ms': 365933,
#    'time_signature': 4}],
#  [{'danceability': 0.68,
#    'energy': 0.549,
#    'key': 9,
#    'loudness': -12.331,
#    'mode': 1,
#    'speechiness': 0.0947,
#    'acousticness': 0.272,
#    'instrumentalness': 0,
#    'liveness': 0.116,
#    'valence': 0.969,
#    'tempo': 83.497,
#    'type': 'audio_features',
#    'id': '5RKjI6OfKO2sjMpx67bkmm',
#    'uri': 'spotify:track:5RKjI6OfKO2sjMpx67bkmm',
#    'track_href': 'https://api.spotify.com/v1/tracks/5RKjI6OfKO2sjMpx67bkmm',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5RKjI6OfKO2sjMpx67bkmm',
#    'duration_ms': 151227,
#    'time_signature': 4}],
#  [{'danceability': 0.736,
#    'energy': 0.548,
#    'key': 0,
#    'loudness': -6.261,
#    'mode': 1,
#    'speechiness': 0.0362,
#    'acousticness': 0.278,
#    'instrumentalness': 0.000597,
#    'liveness': 0.177,
#    'valence': 0.731,
#    'tempo': 128.439,
#    'type': 'audio_features',
#    'id': '73iwWviVbnrQRuzbsz023q',
#    'uri': 'spotify:track:73iwWviVbnrQRuzbsz023q',
#    'track_href': 'https://api.spotify.com/v1/tracks/73iwWviVbnrQRuzbsz023q',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/73iwWviVbnrQRuzbsz023q',
#    'duration_ms': 164733,
#    'time_signature': 4}],
#  [{'danceability': 0.747,
#    'energy': 0.68,
#    'key': 1,
#    'loudness': -6.187,
#    'mode': 1,
#    'speechiness': 0.0346,
#    'acousticness': 0.0107,
#    'instrumentalness': 0.803,
#    'liveness': 0.0964,
#    'valence': 0.594,
#    'tempo': 93.804,
#    'type': 'audio_features',
#    'id': '5Nn2Dj7OQsGL6pgQ9iIzPp',
#    'uri': 'spotify:track:5Nn2Dj7OQsGL6pgQ9iIzPp',
#    'track_href': 'https://api.spotify.com/v1/tracks/5Nn2Dj7OQsGL6pgQ9iIzPp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5Nn2Dj7OQsGL6pgQ9iIzPp',
#    'duration_ms': 317933,
#    'time_signature': 4}],
#  [{'danceability': 0.654,
#    'energy': 0.477,
#    'key': 4,
#    'loudness': -10.337,
#    'mode': 0,
#    'speechiness': 0.0706,
#    'acousticness': 0.424,
#    'instrumentalness': 0,
#    'liveness': 0.218,
#    'valence': 0.514,
#    'tempo': 95.054,
#    'type': 'audio_features',
#    'id': '2D2p0eif9odHKFnRMIQU0w',
#    'uri': 'spotify:track:2D2p0eif9odHKFnRMIQU0w',
#    'track_href': 'https://api.spotify.com/v1/tracks/2D2p0eif9odHKFnRMIQU0w',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2D2p0eif9odHKFnRMIQU0w',
#    'duration_ms': 242277,
#    'time_signature': 4}],
#  [{'danceability': 0.412,
#    'energy': 0.576,
#    'key': 9,
#    'loudness': -9.403,
#    'mode': 0,
#    'speechiness': 0.0277,
#    'acousticness': 0.681,
#    'instrumentalness': 0.0315,
#    'liveness': 0.141,
#    'valence': 0.264,
#    'tempo': 97.289,
#    'type': 'audio_features',
#    'id': '0j1YhB6z2ucnz200ueyp2B',
#    'uri': 'spotify:track:0j1YhB6z2ucnz200ueyp2B',
#    'track_href': 'https://api.spotify.com/v1/tracks/0j1YhB6z2ucnz200ueyp2B',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0j1YhB6z2ucnz200ueyp2B',
#    'duration_ms': 208627,
#    'time_signature': 4}],
#  [{'danceability': 0.669,
#    'energy': 0.153,
#    'key': 2,
#    'loudness': -13.926,
#    'mode': 1,
#    'speechiness': 0.0304,
#    'acousticness': 0.693,
#    'instrumentalness': 6.85e-05,
#    'liveness': 0.121,
#    'valence': 0.37,
#    'tempo': 106.184,
#    'type': 'audio_features',
#    'id': '0J22fYZReDIiD5dBLzOyzl',
#    'uri': 'spotify:track:0J22fYZReDIiD5dBLzOyzl',
#    'track_href': 'https://api.spotify.com/v1/tracks/0J22fYZReDIiD5dBLzOyzl',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0J22fYZReDIiD5dBLzOyzl',
#    'duration_ms': 216000,
#    'time_signature': 4}],
#  [{'danceability': 0.888,
#    'energy': 0.415,
#    'key': 0,
#    'loudness': -6.583,
#    'mode': 1,
#    'speechiness': 0.0405,
#    'acousticness': 0.114,
#    'instrumentalness': 0.13,
#    'liveness': 0.0905,
#    'valence': 0.671,
#    'tempo': 93.714,
#    'type': 'audio_features',
#    'id': '6NhuC3eym57grcOoZo4Jst',
#    'uri': 'spotify:track:6NhuC3eym57grcOoZo4Jst',
#    'track_href': 'https://api.spotify.com/v1/tracks/6NhuC3eym57grcOoZo4Jst',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6NhuC3eym57grcOoZo4Jst',
#    'duration_ms': 219427,
#    'time_signature': 4}],
#  [{'danceability': 0.717,
#    'energy': 0.604,
#    'key': 3,
#    'loudness': -6.194,
#    'mode': 1,
#    'speechiness': 0.141,
#    'acousticness': 0.0772,
#    'instrumentalness': 0.000243,
#    'liveness': 0.338,
#    'valence': 0.585,
#    'tempo': 81.549,
#    'type': 'audio_features',
#    'id': '4V7vcixwGO7cwAdxJCYVYs',
#    'uri': 'spotify:track:4V7vcixwGO7cwAdxJCYVYs',
#    'track_href': 'https://api.spotify.com/v1/tracks/4V7vcixwGO7cwAdxJCYVYs',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4V7vcixwGO7cwAdxJCYVYs',
#    'duration_ms': 243253,
#    'time_signature': 4}],
#  [{'danceability': 0.56,
#    'energy': 0.113,
#    'key': 6,
#    'loudness': -14.755,
#    'mode': 0,
#    'speechiness': 0.0412,
#    'acousticness': 0.959,
#    'instrumentalness': 0.0143,
#    'liveness': 0.113,
#    'valence': 0.141,
#    'tempo': 156.795,
#    'type': 'audio_features',
#    'id': '4u0XMQsb1WPZnC9mlM68A4',
#    'uri': 'spotify:track:4u0XMQsb1WPZnC9mlM68A4',
#    'track_href': 'https://api.spotify.com/v1/tracks/4u0XMQsb1WPZnC9mlM68A4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4u0XMQsb1WPZnC9mlM68A4',
#    'duration_ms': 251613,
#    'time_signature': 4}],
#  [{'danceability': 0.26,
#    'energy': 0.257,
#    'key': 7,
#    'loudness': -10.021,
#    'mode': 1,
#    'speechiness': 0.0313,
#    'acousticness': 0.73,
#    'instrumentalness': 2.43e-05,
#    'liveness': 0.0982,
#    'valence': 0.394,
#    'tempo': 178.825,
#    'type': 'audio_features',
#    'id': '2HcBa4FbX56sHRUvG8A0lr',
#    'uri': 'spotify:track:2HcBa4FbX56sHRUvG8A0lr',
#    'track_href': 'https://api.spotify.com/v1/tracks/2HcBa4FbX56sHRUvG8A0lr',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2HcBa4FbX56sHRUvG8A0lr',
#    'duration_ms': 169800,
#    'time_signature': 3}],
#  [{'danceability': 0.712,
#    'energy': 0.793,
#    'key': 6,
#    'loudness': -3.488,
#    'mode': 1,
#    'speechiness': 0.0374,
#    'acousticness': 0.333,
#    'instrumentalness': 0.00305,
#    'liveness': 0.103,
#    'valence': 0.885,
#    'tempo': 109.631,
#    'type': 'audio_features',
#    'id': '7iuXdT8CcAik4crjwJ2NVf',
#    'uri': 'spotify:track:7iuXdT8CcAik4crjwJ2NVf',
#    'track_href': 'https://api.spotify.com/v1/tracks/7iuXdT8CcAik4crjwJ2NVf',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7iuXdT8CcAik4crjwJ2NVf',
#    'duration_ms': 174387,
#    'time_signature': 4}],
#  [{'danceability': 0.609,
#    'energy': 0.668,
#    'key': 4,
#    'loudness': -10.502,
#    'mode': 0,
#    'speechiness': 0.0459,
#    'acousticness': 0.594,
#    'instrumentalness': 0.121,
#    'liveness': 0.113,
#    'valence': 0.789,
#    'tempo': 124.67,
#    'type': 'audio_features',
#    'id': '1CzcrUxj97grUPWZ8HC3Dz',
#    'uri': 'spotify:track:1CzcrUxj97grUPWZ8HC3Dz',
#    'track_href': 'https://api.spotify.com/v1/tracks/1CzcrUxj97grUPWZ8HC3Dz',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1CzcrUxj97grUPWZ8HC3Dz',
#    'duration_ms': 289293,
#    'time_signature': 4}],
#  [{'danceability': 0.829,
#    'energy': 0.248,
#    'key': 5,
#    'loudness': -16.94,
#    'mode': 1,
#    'speechiness': 0.169,
#    'acousticness': 0.531,
#    'instrumentalness': 0,
#    'liveness': 0.0732,
#    'valence': 0.786,
#    'tempo': 121.444,
#    'type': 'audio_features',
#    'id': '3GppcLIGlSlvujXgR0pPRt',
#    'uri': 'spotify:track:3GppcLIGlSlvujXgR0pPRt',
#    'track_href': 'https://api.spotify.com/v1/tracks/3GppcLIGlSlvujXgR0pPRt',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3GppcLIGlSlvujXgR0pPRt',
#    'duration_ms': 177733,
#    'time_signature': 4}],
#  [{'danceability': 0.713,
#    'energy': 0.623,
#    'key': 0,
#    'loudness': -6.714,
#    'mode': 1,
#    'speechiness': 0.129,
#    'acousticness': 0.192,
#    'instrumentalness': 0,
#    'liveness': 0.0607,
#    'valence': 0.566,
#    'tempo': 95.1,
#    'type': 'audio_features',
#    'id': '4qaXgj5TezCSCZD6tnGNp0',
#    'uri': 'spotify:track:4qaXgj5TezCSCZD6tnGNp0',
#    'track_href': 'https://api.spotify.com/v1/tracks/4qaXgj5TezCSCZD6tnGNp0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4qaXgj5TezCSCZD6tnGNp0',
#    'duration_ms': 178360,
#    'time_signature': 4}],
#  [{'danceability': 0.628,
#    'energy': 0.719,
#    'key': 8,
#    'loudness': -5.443,
#    'mode': 1,
#    'speechiness': 0.041,
#    'acousticness': 0.0138,
#    'instrumentalness': 0.0951,
#    'liveness': 0.206,
#    'valence': 0.371,
#    'tempo': 134.071,
#    'type': 'audio_features',
#    'id': '42G8Aqqv0sKApmItJvJ8dx',
#    'uri': 'spotify:track:42G8Aqqv0sKApmItJvJ8dx',
#    'track_href': 'https://api.spotify.com/v1/tracks/42G8Aqqv0sKApmItJvJ8dx',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/42G8Aqqv0sKApmItJvJ8dx',
#    'duration_ms': 368277,
#    'time_signature': 4}],
#  [{'danceability': 0.735,
#    'energy': 0.555,
#    'key': 1,
#    'loudness': -8.84,
#    'mode': 0,
#    'speechiness': 0.0366,
#    'acousticness': 0.382,
#    'instrumentalness': 0.856,
#    'liveness': 0.0952,
#    'valence': 0.523,
#    'tempo': 100.01,
#    'type': 'audio_features',
#    'id': '3WS7spXVlbeC5kjePmHMQW',
#    'uri': 'spotify:track:3WS7spXVlbeC5kjePmHMQW',
#    'track_href': 'https://api.spotify.com/v1/tracks/3WS7spXVlbeC5kjePmHMQW',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3WS7spXVlbeC5kjePmHMQW',
#    'duration_ms': 277975,
#    'time_signature': 4}],
#  [{'danceability': 0.594,
#    'energy': 0.676,
#    'key': 5,
#    'loudness': -9.552,
#    'mode': 1,
#    'speechiness': 0.0528,
#    'acousticness': 0.0267,
#    'instrumentalness': 0.00541,
#    'liveness': 0.905,
#    'valence': 0.898,
#    'tempo': 110.71,
#    'type': 'audio_features',
#    'id': '5O6mz4qn6q7MSKubAzRnDW',
#    'uri': 'spotify:track:5O6mz4qn6q7MSKubAzRnDW',
#    'track_href': 'https://api.spotify.com/v1/tracks/5O6mz4qn6q7MSKubAzRnDW',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5O6mz4qn6q7MSKubAzRnDW',
#    'duration_ms': 162907,
#    'time_signature': 4}],
#  [{'danceability': 0.639,
#    'energy': 0.452,
#    'key': 7,
#    'loudness': -7.199,
#    'mode': 1,
#    'speechiness': 0.0324,
#    'acousticness': 0.00258,
#    'instrumentalness': 0.00153,
#    'liveness': 0.0473,
#    'valence': 0.487,
#    'tempo': 100.019,
#    'type': 'audio_features',
#    'id': '43p0RNDfD6lSnHrQJUeffT',
#    'uri': 'spotify:track:43p0RNDfD6lSnHrQJUeffT',
#    'track_href': 'https://api.spotify.com/v1/tracks/43p0RNDfD6lSnHrQJUeffT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43p0RNDfD6lSnHrQJUeffT',
#    'duration_ms': 221946,
#    'time_signature': 4}],
#  [{'danceability': 0.401,
#    'energy': 0.534,
#    'key': 7,
#    'loudness': -6.576,
#    'mode': 1,
#    'speechiness': 0.0524,
#    'acousticness': 0.59,
#    'instrumentalness': 7.41e-05,
#    'liveness': 0.981,
#    'valence': 0.396,
#    'tempo': 80.718,
#    'type': 'audio_features',
#    'id': '1l3bkDAw1rxeGrPweih1jh',
#    'uri': 'spotify:track:1l3bkDAw1rxeGrPweih1jh',
#    'track_href': 'https://api.spotify.com/v1/tracks/1l3bkDAw1rxeGrPweih1jh',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1l3bkDAw1rxeGrPweih1jh',
#    'duration_ms': 358933,
#    'time_signature': 4}],
#  [{'danceability': 0.537,
#    'energy': 0.874,
#    'key': 5,
#    'loudness': -9.656,
#    'mode': 1,
#    'speechiness': 0.0704,
#    'acousticness': 0.186,
#    'instrumentalness': 0.00115,
#    'liveness': 0.405,
#    'valence': 0.615,
#    'tempo': 97.381,
#    'type': 'audio_features',
#    'id': '0DKvBAgkajew9Mi2ZMZRXo',
#    'uri': 'spotify:track:0DKvBAgkajew9Mi2ZMZRXo',
#    'track_href': 'https://api.spotify.com/v1/tracks/0DKvBAgkajew9Mi2ZMZRXo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0DKvBAgkajew9Mi2ZMZRXo',
#    'duration_ms': 193000,
#    'time_signature': 4}],
#  [{'danceability': 0.404,
#    'energy': 0.763,
#    'key': 10,
#    'loudness': -5.071,
#    'mode': 1,
#    'speechiness': 0.0346,
#    'acousticness': 0.419,
#    'instrumentalness': 0,
#    'liveness': 0.129,
#    'valence': 0.699,
#    'tempo': 184.012,
#    'type': 'audio_features',
#    'id': '56ga742AkJ7eL8sVZFWaag',
#    'uri': 'spotify:track:56ga742AkJ7eL8sVZFWaag',
#    'track_href': 'https://api.spotify.com/v1/tracks/56ga742AkJ7eL8sVZFWaag',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/56ga742AkJ7eL8sVZFWaag',
#    'duration_ms': 225960,
#    'time_signature': 4}],
#  [{'danceability': 0.757,
#    'energy': 0.256,
#    'key': 11,
#    'loudness': -16.435,
#    'mode': 0,
#    'speechiness': 0.101,
#    'acousticness': 0.963,
#    'instrumentalness': 0.11,
#    'liveness': 0.107,
#    'valence': 0.538,
#    'tempo': 117.462,
#    'type': 'audio_features',
#    'id': '3Iizl7lLyHn0uWS64BOacY',
#    'uri': 'spotify:track:3Iizl7lLyHn0uWS64BOacY',
#    'track_href': 'https://api.spotify.com/v1/tracks/3Iizl7lLyHn0uWS64BOacY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3Iizl7lLyHn0uWS64BOacY',
#    'duration_ms': 218291,
#    'time_signature': 4}],
#  [{'danceability': 0.623,
#    'energy': 0.553,
#    'key': 7,
#    'loudness': -7.441,
#    'mode': 1,
#    'speechiness': 0.0252,
#    'acousticness': 0.581,
#    'instrumentalness': 1.44e-06,
#    'liveness': 0.0725,
#    'valence': 0.752,
#    'tempo': 87.992,
#    'type': 'audio_features',
#    'id': '2juY7nhQdfhhc4UHOOq2jq',
#    'uri': 'spotify:track:2juY7nhQdfhhc4UHOOq2jq',
#    'track_href': 'https://api.spotify.com/v1/tracks/2juY7nhQdfhhc4UHOOq2jq',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2juY7nhQdfhhc4UHOOq2jq',
#    'duration_ms': 256120,
#    'time_signature': 4}],
#  [{'danceability': 0.743,
#    'energy': 0.674,
#    'key': 2,
#    'loudness': -7.683,
#    'mode': 1,
#    'speechiness': 0.0323,
#    'acousticness': 0.361,
#    'instrumentalness': 8.93e-05,
#    'liveness': 0.0696,
#    'valence': 0.829,
#    'tempo': 112.906,
#    'type': 'audio_features',
#    'id': '5jQPDVjgSGnNYl8G3H3qul',
#    'uri': 'spotify:track:5jQPDVjgSGnNYl8G3H3qul',
#    'track_href': 'https://api.spotify.com/v1/tracks/5jQPDVjgSGnNYl8G3H3qul',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5jQPDVjgSGnNYl8G3H3qul',
#    'duration_ms': 243777,
#    'time_signature': 4}],
#  [{'danceability': 0.646,
#    'energy': 0.474,
#    'key': 2,
#    'loudness': -11.186,
#    'mode': 1,
#    'speechiness': 0.0483,
#    'acousticness': 0.341,
#    'instrumentalness': 0.000213,
#    'liveness': 0.1,
#    'valence': 0.67,
#    'tempo': 127.82,
#    'type': 'audio_features',
#    'id': '77ku3NBquiW8kJIu2Ldz2m',
#    'uri': 'spotify:track:77ku3NBquiW8kJIu2Ldz2m',
#    'track_href': 'https://api.spotify.com/v1/tracks/77ku3NBquiW8kJIu2Ldz2m',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/77ku3NBquiW8kJIu2Ldz2m',
#    'duration_ms': 241413,
#    'time_signature': 4}],
#  [{'danceability': 0.602,
#    'energy': 0.797,
#    'key': 5,
#    'loudness': -6.706,
#    'mode': 0,
#    'speechiness': 0.031,
#    'acousticness': 0.00582,
#    'instrumentalness': 0,
#    'liveness': 0.107,
#    'valence': 0.808,
#    'tempo': 124.923,
#    'type': 'audio_features',
#    'id': '46rPGnMRUK2MN1jdhZipic',
#    'uri': 'spotify:track:46rPGnMRUK2MN1jdhZipic',
#    'track_href': 'https://api.spotify.com/v1/tracks/46rPGnMRUK2MN1jdhZipic',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/46rPGnMRUK2MN1jdhZipic',
#    'duration_ms': 212000,
#    'time_signature': 4}],
#  [{'danceability': 0.881,
#    'energy': 0.761,
#    'key': 11,
#    'loudness': -6.295,
#    'mode': 0,
#    'speechiness': 0.0324,
#    'acousticness': 0.0884,
#    'instrumentalness': 0.682,
#    'liveness': 0.0759,
#    'valence': 0.97,
#    'tempo': 119.982,
#    'type': 'audio_features',
#    'id': '3F1VXvS7N6Jy0RN09WdBKw',
#    'uri': 'spotify:track:3F1VXvS7N6Jy0RN09WdBKw',
#    'track_href': 'https://api.spotify.com/v1/tracks/3F1VXvS7N6Jy0RN09WdBKw',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3F1VXvS7N6Jy0RN09WdBKw',
#    'duration_ms': 254160,
#    'time_signature': 4}],
#  [{'danceability': 0.864,
#    'energy': 0.555,
#    'key': 4,
#    'loudness': -9.904,
#    'mode': 0,
#    'speechiness': 0.104,
#    'acousticness': 0.0539,
#    'instrumentalness': 0.698,
#    'liveness': 0.0695,
#    'valence': 0.306,
#    'tempo': 113.002,
#    'type': 'audio_features',
#    'id': '67bEWV1fH73M4Utu4Z13Kp',
#    'uri': 'spotify:track:67bEWV1fH73M4Utu4Z13Kp',
#    'track_href': 'https://api.spotify.com/v1/tracks/67bEWV1fH73M4Utu4Z13Kp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/67bEWV1fH73M4Utu4Z13Kp',
#    'duration_ms': 454513,
#    'time_signature': 4}],
#  [{'danceability': 0.562,
#    'energy': 0.806,
#    'key': 11,
#    'loudness': -4.588,
#    'mode': 1,
#    'speechiness': 0.0484,
#    'acousticness': 0.0643,
#    'instrumentalness': 6.05e-06,
#    'liveness': 0.233,
#    'valence': 0.523,
#    'tempo': 127.993,
#    'type': 'audio_features',
#    'id': '0ErHM0nECzE60Jnt0NMeXy',
#    'uri': 'spotify:track:0ErHM0nECzE60Jnt0NMeXy',
#    'track_href': 'https://api.spotify.com/v1/tracks/0ErHM0nECzE60Jnt0NMeXy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0ErHM0nECzE60Jnt0NMeXy',
#    'duration_ms': 188080,
#    'time_signature': 4}],
#  [{'danceability': 0.526,
#    'energy': 0.91,
#    'key': 2,
#    'loudness': -5.118,
#    'mode': 0,
#    'speechiness': 0.0329,
#    'acousticness': 0.542,
#    'instrumentalness': 0.00197,
#    'liveness': 0.521,
#    'valence': 0.909,
#    'tempo': 95.451,
#    'type': 'audio_features',
#    'id': '2kIUsdizVjgQfGHvJTZtY5',
#    'uri': 'spotify:track:2kIUsdizVjgQfGHvJTZtY5',
#    'track_href': 'https://api.spotify.com/v1/tracks/2kIUsdizVjgQfGHvJTZtY5',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2kIUsdizVjgQfGHvJTZtY5',
#    'duration_ms': 231880,
#    'time_signature': 4}],
#  [{'danceability': 0.466,
#    'energy': 0.927,
#    'key': 9,
#    'loudness': -5.146,
#    'mode': 0,
#    'speechiness': 0.0375,
#    'acousticness': 0.042,
#    'instrumentalness': 0.792,
#    'liveness': 0.0364,
#    'valence': 0.976,
#    'tempo': 178.703,
#    'type': 'audio_features',
#    'id': '1OJlJ1gEfx2dSlr59iWMAA',
#    'uri': 'spotify:track:1OJlJ1gEfx2dSlr59iWMAA',
#    'track_href': 'https://api.spotify.com/v1/tracks/1OJlJ1gEfx2dSlr59iWMAA',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1OJlJ1gEfx2dSlr59iWMAA',
#    'duration_ms': 211440,
#    'time_signature': 4}],
#  [{'danceability': 0.736,
#    'energy': 0.563,
#    'key': 7,
#    'loudness': -9.779,
#    'mode': 1,
#    'speechiness': 0.0704,
#    'acousticness': 0.0366,
#    'instrumentalness': 0.0094,
#    'liveness': 0.13,
#    'valence': 0.542,
#    'tempo': 87.986,
#    'type': 'audio_features',
#    'id': '1PCBv0e6guRL2JvvAgXlcJ',
#    'uri': 'spotify:track:1PCBv0e6guRL2JvvAgXlcJ',
#    'track_href': 'https://api.spotify.com/v1/tracks/1PCBv0e6guRL2JvvAgXlcJ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1PCBv0e6guRL2JvvAgXlcJ',
#    'duration_ms': 245453,
#    'time_signature': 4}],
#  [{'danceability': 0.226,
#    'energy': 0.926,
#    'key': 8,
#    'loudness': -5.749,
#    'mode': 1,
#    'speechiness': 0.0817,
#    'acousticness': 0.00589,
#    'instrumentalness': 2.5e-05,
#    'liveness': 0.296,
#    'valence': 0.59,
#    'tempo': 168.713,
#    'type': 'audio_features',
#    'id': '34PLpJWhWw4IFFAd2PWgo5',
#    'uri': 'spotify:track:34PLpJWhWw4IFFAd2PWgo5',
#    'track_href': 'https://api.spotify.com/v1/tracks/34PLpJWhWw4IFFAd2PWgo5',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/34PLpJWhWw4IFFAd2PWgo5',
#    'duration_ms': 166800,
#    'time_signature': 4}],
#  [{'danceability': 0.539,
#    'energy': 0.897,
#    'key': 0,
#    'loudness': -5.337,
#    'mode': 1,
#    'speechiness': 0.0314,
#    'acousticness': 0.0136,
#    'instrumentalness': 0.0027,
#    'liveness': 0.358,
#    'valence': 0.443,
#    'tempo': 98.007,
#    'type': 'audio_features',
#    'id': '0SilRhksdfJMKVITSJOxIo',
#    'uri': 'spotify:track:0SilRhksdfJMKVITSJOxIo',
#    'track_href': 'https://api.spotify.com/v1/tracks/0SilRhksdfJMKVITSJOxIo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0SilRhksdfJMKVITSJOxIo',
#    'duration_ms': 256813,
#    'time_signature': 4}],
#  [{'danceability': 0.701,
#    'energy': 0.66,
#    'key': 5,
#    'loudness': -6.075,
#    'mode': 0,
#    'speechiness': 0.0303,
#    'acousticness': 0.0489,
#    'instrumentalness': 2.84e-05,
#    'liveness': 0.354,
#    'valence': 0.601,
#    'tempo': 98.003,
#    'type': 'audio_features',
#    'id': '2Arl7cRrFiuDiHQjdMEXOU',
#    'uri': 'spotify:track:2Arl7cRrFiuDiHQjdMEXOU',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Arl7cRrFiuDiHQjdMEXOU',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Arl7cRrFiuDiHQjdMEXOU',
#    'duration_ms': 169373,
#    'time_signature': 4}],
#  [{'danceability': 0.786,
#    'energy': 0.906,
#    'key': 9,
#    'loudness': -8.266,
#    'mode': 0,
#    'speechiness': 0.0398,
#    'acousticness': 0.0286,
#    'instrumentalness': 0.704,
#    'liveness': 0.471,
#    'valence': 0.823,
#    'tempo': 132.017,
#    'type': 'audio_features',
#    'id': '0TrkWE0Lj5hSftkPGfmppy',
#    'uri': 'spotify:track:0TrkWE0Lj5hSftkPGfmppy',
#    'track_href': 'https://api.spotify.com/v1/tracks/0TrkWE0Lj5hSftkPGfmppy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0TrkWE0Lj5hSftkPGfmppy',
#    'duration_ms': 262801,
#    'time_signature': 4}],
#  [{'danceability': 0.688,
#    'energy': 0.797,
#    'key': 0,
#    'loudness': -4.627,
#    'mode': 1,
#    'speechiness': 0.0771,
#    'acousticness': 0.09,
#    'instrumentalness': 0,
#    'liveness': 0.0741,
#    'valence': 0.629,
#    'tempo': 152.051,
#    'type': 'audio_features',
#    'id': '6Tv0CGfc6KKJf2SR91GTfS',
#    'uri': 'spotify:track:6Tv0CGfc6KKJf2SR91GTfS',
#    'track_href': 'https://api.spotify.com/v1/tracks/6Tv0CGfc6KKJf2SR91GTfS',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6Tv0CGfc6KKJf2SR91GTfS',
#    'duration_ms': 164211,
#    'time_signature': 4}],
#  [{'danceability': 0.759,
#    'energy': 0.794,
#    'key': 10,
#    'loudness': -5.594,
#    'mode': 0,
#    'speechiness': 0.197,
#    'acousticness': 0.0416,
#    'instrumentalness': 0.000147,
#    'liveness': 0.0801,
#    'valence': 0.658,
#    'tempo': 93.485,
#    'type': 'audio_features',
#    'id': '2TY9MWNZJ3s78XvOlEBTji',
#    'uri': 'spotify:track:2TY9MWNZJ3s78XvOlEBTji',
#    'track_href': 'https://api.spotify.com/v1/tracks/2TY9MWNZJ3s78XvOlEBTji',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2TY9MWNZJ3s78XvOlEBTji',
#    'duration_ms': 278773,
#    'time_signature': 4}],
#  [{'danceability': 0.73,
#    'energy': 0.706,
#    'key': 8,
#    'loudness': -6.04,
#    'mode': 0,
#    'speechiness': 0.325,
#    'acousticness': 0.0299,
#    'instrumentalness': 0,
#    'liveness': 0.383,
#    'valence': 0.83,
#    'tempo': 79.694,
#    'type': 'audio_features',
#    'id': '44NFd0LGevT1cxH8BoPZSP',
#    'uri': 'spotify:track:44NFd0LGevT1cxH8BoPZSP',
#    'track_href': 'https://api.spotify.com/v1/tracks/44NFd0LGevT1cxH8BoPZSP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/44NFd0LGevT1cxH8BoPZSP',
#    'duration_ms': 224453,
#    'time_signature': 4}],
#  [{'danceability': 0.625,
#    'energy': 0.553,
#    'key': 8,
#    'loudness': -9.483,
#    'mode': 0,
#    'speechiness': 0.0378,
#    'acousticness': 0.0396,
#    'instrumentalness': 0.0532,
#    'liveness': 0.139,
#    'valence': 0.331,
#    'tempo': 140.015,
#    'type': 'audio_features',
#    'id': '0FCkSS3ai4slPIvoOfu6yO',
#    'uri': 'spotify:track:0FCkSS3ai4slPIvoOfu6yO',
#    'track_href': 'https://api.spotify.com/v1/tracks/0FCkSS3ai4slPIvoOfu6yO',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0FCkSS3ai4slPIvoOfu6yO',
#    'duration_ms': 290692,
#    'time_signature': 4}],
#  [{'danceability': 0.746,
#    'energy': 0.273,
#    'key': 5,
#    'loudness': -16.63,
#    'mode': 1,
#    'speechiness': 0.0573,
#    'acousticness': 0.606,
#    'instrumentalness': 0.0168,
#    'liveness': 0.0526,
#    'valence': 0.502,
#    'tempo': 101.952,
#    'type': 'audio_features',
#    'id': '7kWhdmRYv8CqbWNqfojqVd',
#    'uri': 'spotify:track:7kWhdmRYv8CqbWNqfojqVd',
#    'track_href': 'https://api.spotify.com/v1/tracks/7kWhdmRYv8CqbWNqfojqVd',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7kWhdmRYv8CqbWNqfojqVd',
#    'duration_ms': 199400,
#    'time_signature': 4}],
#  [{'danceability': 0.333,
#    'energy': 0.834,
#    'key': 4,
#    'loudness': -9.076,
#    'mode': 1,
#    'speechiness': 0.223,
#    'acousticness': 0.675,
#    'instrumentalness': 0.778,
#    'liveness': 0.487,
#    'valence': 0.127,
#    'tempo': 72.411,
#    'type': 'audio_features',
#    'id': '0VAFMyW6EXtZllWBnmKbSN',
#    'uri': 'spotify:track:0VAFMyW6EXtZllWBnmKbSN',
#    'track_href': 'https://api.spotify.com/v1/tracks/0VAFMyW6EXtZllWBnmKbSN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0VAFMyW6EXtZllWBnmKbSN',
#    'duration_ms': 360444,
#    'time_signature': 4}],
#  [{'danceability': 0.658,
#    'energy': 0.847,
#    'key': 0,
#    'loudness': -6.04,
#    'mode': 1,
#    'speechiness': 0.0598,
#    'acousticness': 0.0954,
#    'instrumentalness': 0.036,
#    'liveness': 0.273,
#    'valence': 0.779,
#    'tempo': 127.092,
#    'type': 'audio_features',
#    'id': '57mY4qUaUegA3jvoyoz7oT',
#    'uri': 'spotify:track:57mY4qUaUegA3jvoyoz7oT',
#    'track_href': 'https://api.spotify.com/v1/tracks/57mY4qUaUegA3jvoyoz7oT',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/57mY4qUaUegA3jvoyoz7oT',
#    'duration_ms': 257320,
#    'time_signature': 4}],
#  [{'danceability': 0.466,
#    'energy': 0.688,
#    'key': 9,
#    'loudness': -10.527,
#    'mode': 1,
#    'speechiness': 0.0621,
#    'acousticness': 0.0233,
#    'instrumentalness': 1.48e-05,
#    'liveness': 0.179,
#    'valence': 0.964,
#    'tempo': 174.191,
#    'type': 'audio_features',
#    'id': '7b9r5votRwq8QYOXSUUwfQ',
#    'uri': 'spotify:track:7b9r5votRwq8QYOXSUUwfQ',
#    'track_href': 'https://api.spotify.com/v1/tracks/7b9r5votRwq8QYOXSUUwfQ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7b9r5votRwq8QYOXSUUwfQ',
#    'duration_ms': 182693,
#    'time_signature': 4}],
#  [{'danceability': 0.499,
#    'energy': 0.69,
#    'key': 9,
#    'loudness': -8.156,
#    'mode': 0,
#    'speechiness': 0.0277,
#    'acousticness': 0.00766,
#    'instrumentalness': 0.112,
#    'liveness': 0.33,
#    'valence': 0.912,
#    'tempo': 148.393,
#    'type': 'audio_features',
#    'id': '0R86LncvIGAt5299oZsfmp',
#    'uri': 'spotify:track:0R86LncvIGAt5299oZsfmp',
#    'track_href': 'https://api.spotify.com/v1/tracks/0R86LncvIGAt5299oZsfmp',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0R86LncvIGAt5299oZsfmp',
#    'duration_ms': 120883,
#    'time_signature': 4}],
#  [{'danceability': 0.754,
#    'energy': 0.534,
#    'key': 11,
#    'loudness': -8.932,
#    'mode': 1,
#    'speechiness': 0.213,
#    'acousticness': 0.317,
#    'instrumentalness': 0.162,
#    'liveness': 0.163,
#    'valence': 0.498,
#    'tempo': 97.113,
#    'type': 'audio_features',
#    'id': '1Ll36rj3jqbmRVSc3g1RAM',
#    'uri': 'spotify:track:1Ll36rj3jqbmRVSc3g1RAM',
#    'track_href': 'https://api.spotify.com/v1/tracks/1Ll36rj3jqbmRVSc3g1RAM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1Ll36rj3jqbmRVSc3g1RAM',
#    'duration_ms': 351693,
#    'time_signature': 4}],
#  [{'danceability': 0.792,
#    'energy': 0.568,
#    'key': 11,
#    'loudness': -9.142,
#    'mode': 1,
#    'speechiness': 0.0456,
#    'acousticness': 0.325,
#    'instrumentalness': 0.438,
#    'liveness': 0.083,
#    'valence': 0.244,
#    'tempo': 103.981,
#    'type': 'audio_features',
#    'id': '1ZPc6TYeCaeSgu8W8bV5jD',
#    'uri': 'spotify:track:1ZPc6TYeCaeSgu8W8bV5jD',
#    'track_href': 'https://api.spotify.com/v1/tracks/1ZPc6TYeCaeSgu8W8bV5jD',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ZPc6TYeCaeSgu8W8bV5jD',
#    'duration_ms': 264675,
#    'time_signature': 4}],
#  [{'danceability': 0.696,
#    'energy': 0.792,
#    'key': 6,
#    'loudness': -8.568,
#    'mode': 1,
#    'speechiness': 0.0564,
#    'acousticness': 0.0743,
#    'instrumentalness': 0.914,
#    'liveness': 0.474,
#    'valence': 0.698,
#    'tempo': 109.257,
#    'type': 'audio_features',
#    'id': '75xnyitqdY8A3JyTZxQKxc',
#    'uri': 'spotify:track:75xnyitqdY8A3JyTZxQKxc',
#    'track_href': 'https://api.spotify.com/v1/tracks/75xnyitqdY8A3JyTZxQKxc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/75xnyitqdY8A3JyTZxQKxc',
#    'duration_ms': 200101,
#    'time_signature': 4}],
#  [{'danceability': 0.817,
#    'energy': 0.297,
#    'key': 0,
#    'loudness': -14.13,
#    'mode': 1,
#    'speechiness': 0.0383,
#    'acousticness': 0.818,
#    'instrumentalness': 0.00108,
#    'liveness': 0.139,
#    'valence': 0.913,
#    'tempo': 124.167,
#    'type': 'audio_features',
#    'id': '5z3uleqWZt08aY3p8u9sIc',
#    'uri': 'spotify:track:5z3uleqWZt08aY3p8u9sIc',
#    'track_href': 'https://api.spotify.com/v1/tracks/5z3uleqWZt08aY3p8u9sIc',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5z3uleqWZt08aY3p8u9sIc',
#    'duration_ms': 191467,
#    'time_signature': 4}],
#  [{'danceability': 0.771,
#    'energy': 0.29,
#    'key': 10,
#    'loudness': -13.413,
#    'mode': 0,
#    'speechiness': 0.0341,
#    'acousticness': 0.323,
#    'instrumentalness': 0.0316,
#    'liveness': 0.0645,
#    'valence': 0.192,
#    'tempo': 118.003,
#    'type': 'audio_features',
#    'id': '4vELW2hK9eb9R7Q0BNJ3Vh',
#    'uri': 'spotify:track:4vELW2hK9eb9R7Q0BNJ3Vh',
#    'track_href': 'https://api.spotify.com/v1/tracks/4vELW2hK9eb9R7Q0BNJ3Vh',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4vELW2hK9eb9R7Q0BNJ3Vh',
#    'duration_ms': 303586,
#    'time_signature': 4}],
#  [{'danceability': 0.558,
#    'energy': 0.269,
#    'key': 11,
#    'loudness': -13.396,
#    'mode': 0,
#    'speechiness': 0.193,
#    'acousticness': 0.427,
#    'instrumentalness': 0.785,
#    'liveness': 0.107,
#    'valence': 0.58,
#    'tempo': 101.942,
#    'type': 'audio_features',
#    'id': '5nt968onvYmCg8H1ckWEKH',
#    'uri': 'spotify:track:5nt968onvYmCg8H1ckWEKH',
#    'track_href': 'https://api.spotify.com/v1/tracks/5nt968onvYmCg8H1ckWEKH',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5nt968onvYmCg8H1ckWEKH',
#    'duration_ms': 199600,
#    'time_signature': 4}],
#  [{'danceability': 0.564,
#    'energy': 0.645,
#    'key': 7,
#    'loudness': -7.106,
#    'mode': 1,
#    'speechiness': 0.0265,
#    'acousticness': 0.0563,
#    'instrumentalness': 0.0119,
#    'liveness': 0.107,
#    'valence': 0.447,
#    'tempo': 77.213,
#    'type': 'audio_features',
#    'id': '6cDAuJu8XORfSZ9JNL2Ymx',
#    'uri': 'spotify:track:6cDAuJu8XORfSZ9JNL2Ymx',
#    'track_href': 'https://api.spotify.com/v1/tracks/6cDAuJu8XORfSZ9JNL2Ymx',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6cDAuJu8XORfSZ9JNL2Ymx',
#    'duration_ms': 230773,
#    'time_signature': 4}],
#  [{'danceability': 0.826,
#    'energy': 0.423,
#    'key': 4,
#    'loudness': -11.127,
#    'mode': 1,
#    'speechiness': 0.0445,
#    'acousticness': 0.762,
#    'instrumentalness': 0.0689,
#    'liveness': 0.105,
#    'valence': 0.891,
#    'tempo': 100.042,
#    'type': 'audio_features',
#    'id': '0prVUHQu2xr6pI5iEbKtxo',
#    'uri': 'spotify:track:0prVUHQu2xr6pI5iEbKtxo',
#    'track_href': 'https://api.spotify.com/v1/tracks/0prVUHQu2xr6pI5iEbKtxo',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0prVUHQu2xr6pI5iEbKtxo',
#    'duration_ms': 375903,
#    'time_signature': 4}],
#  [{'danceability': 0.58,
#    'energy': 0.829,
#    'key': 0,
#    'loudness': -8.739,
#    'mode': 1,
#    'speechiness': 0.03,
#    'acousticness': 0.36,
#    'instrumentalness': 2.52e-05,
#    'liveness': 0.358,
#    'valence': 0.971,
#    'tempo': 145.402,
#    'type': 'audio_features',
#    'id': '3BC1w99O2lRvpZNYCIhpCP',
#    'uri': 'spotify:track:3BC1w99O2lRvpZNYCIhpCP',
#    'track_href': 'https://api.spotify.com/v1/tracks/3BC1w99O2lRvpZNYCIhpCP',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3BC1w99O2lRvpZNYCIhpCP',
#    'duration_ms': 160653,
#    'time_signature': 4}],
#  [{'danceability': 0.464,
#    'energy': 0.815,
#    'key': 10,
#    'loudness': -6.371,
#    'mode': 1,
#    'speechiness': 0.0368,
#    'acousticness': 0.00871,
#    'instrumentalness': 0.201,
#    'liveness': 0.162,
#    'valence': 0.467,
#    'tempo': 161.845,
#    'type': 'audio_features',
#    'id': '71jGGLe5VtEHjIk5dU2W3S',
#    'uri': 'spotify:track:71jGGLe5VtEHjIk5dU2W3S',
#    'track_href': 'https://api.spotify.com/v1/tracks/71jGGLe5VtEHjIk5dU2W3S',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/71jGGLe5VtEHjIk5dU2W3S',
#    'duration_ms': 298920,
#    'time_signature': 4}],
#  [{'danceability': 0.584,
#    'energy': 0.914,
#    'key': 2,
#    'loudness': -7.279,
#    'mode': 1,
#    'speechiness': 0.0552,
#    'acousticness': 0.0341,
#    'instrumentalness': 0.000196,
#    'liveness': 0.159,
#    'valence': 0.477,
#    'tempo': 104.892,
#    'type': 'audio_features',
#    'id': '664T43rA0ZXvXHRxb3qrAi',
#    'uri': 'spotify:track:664T43rA0ZXvXHRxb3qrAi',
#    'track_href': 'https://api.spotify.com/v1/tracks/664T43rA0ZXvXHRxb3qrAi',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/664T43rA0ZXvXHRxb3qrAi',
#    'duration_ms': 187040,
#    'time_signature': 4}],
#  [{'danceability': 0.661,
#    'energy': 0.39,
#    'key': 4,
#    'loudness': -16.237,
#    'mode': 1,
#    'speechiness': 0.0371,
#    'acousticness': 0.655,
#    'instrumentalness': 3.53e-06,
#    'liveness': 0.0804,
#    'valence': 0.845,
#    'tempo': 107.734,
#    'type': 'audio_features',
#    'id': '43B1vxAfIpBmMbFPyoMAax',
#    'uri': 'spotify:track:43B1vxAfIpBmMbFPyoMAax',
#    'track_href': 'https://api.spotify.com/v1/tracks/43B1vxAfIpBmMbFPyoMAax',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/43B1vxAfIpBmMbFPyoMAax',
#    'duration_ms': 194733,
#    'time_signature': 4}],
#  [{'danceability': 0.719,
#    'energy': 0.816,
#    'key': 7,
#    'loudness': -6.93,
#    'mode': 1,
#    'speechiness': 0.069,
#    'acousticness': 0.00706,
#    'instrumentalness': 0.0225,
#    'liveness': 0.142,
#    'valence': 0.602,
#    'tempo': 126.011,
#    'type': 'audio_features',
#    'id': '10dCb3llSSA47fc1NOLbCj',
#    'uri': 'spotify:track:10dCb3llSSA47fc1NOLbCj',
#    'track_href': 'https://api.spotify.com/v1/tracks/10dCb3llSSA47fc1NOLbCj',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/10dCb3llSSA47fc1NOLbCj',
#    'duration_ms': 220051,
#    'time_signature': 4}],
#  [{'danceability': 0.637,
#    'energy': 0.882,
#    'key': 7,
#    'loudness': -5.218,
#    'mode': 1,
#    'speechiness': 0.178,
#    'acousticness': 0.00199,
#    'instrumentalness': 1.71e-06,
#    'liveness': 0.152,
#    'valence': 0.446,
#    'tempo': 186.05,
#    'type': 'audio_features',
#    'id': '0h7mLhLljtrHOa3aSQpAYC',
#    'uri': 'spotify:track:0h7mLhLljtrHOa3aSQpAYC',
#    'track_href': 'https://api.spotify.com/v1/tracks/0h7mLhLljtrHOa3aSQpAYC',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0h7mLhLljtrHOa3aSQpAYC',
#    'duration_ms': 248493,
#    'time_signature': 4}],
#  [{'danceability': 0.725,
#    'energy': 0.448,
#    'key': 0,
#    'loudness': -8.48,
#    'mode': 1,
#    'speechiness': 0.0413,
#    'acousticness': 0.0297,
#    'instrumentalness': 3.74e-05,
#    'liveness': 0.0605,
#    'valence': 0.441,
#    'tempo': 124.972,
#    'type': 'audio_features',
#    'id': '4bTGxa0SKnLyuTp8TftBvO',
#    'uri': 'spotify:track:4bTGxa0SKnLyuTp8TftBvO',
#    'track_href': 'https://api.spotify.com/v1/tracks/4bTGxa0SKnLyuTp8TftBvO',
# ...
#    'key': 5,
#    'loudness': -9.113,
#    'mode': 0,
#    'speechiness': 0.141,
#    'acousticness': 0.195,
#    'instrumentalness': 0.00228,
#    'liveness': 0.276,
#    'valence': 0.652,
#    'tempo': 110.018,
#    'type': 'audio_features',
#    'id': '5XZyIOvleZYTh0DD399M90',
#    'uri': 'spotify:track:5XZyIOvleZYTh0DD399M90',
#    'track_href': 'https://api.spotify.com/v1/tracks/5XZyIOvleZYTh0DD399M90',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5XZyIOvleZYTh0DD399M90',
#    'duration_ms': 210933,
#    'time_signature': 4}],
#  [{'danceability': 0.73,
#    'energy': 0.72,
#    'key': 1,
#    'loudness': -12.049,
#    'mode': 0,
#    'speechiness': 0.0486,
#    'acousticness': 0.0211,
#    'instrumentalness': 0.0386,
#    'liveness': 0.0452,
#    'valence': 0.687,
#    'tempo': 115.481,
#    'type': 'audio_features',
#    'id': '45UkMHJckFq1RpSRe1l1sy',
#    'uri': 'spotify:track:45UkMHJckFq1RpSRe1l1sy',
#    'track_href': 'https://api.spotify.com/v1/tracks/45UkMHJckFq1RpSRe1l1sy',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/45UkMHJckFq1RpSRe1l1sy',
#    'duration_ms': 367400,
#    'time_signature': 4}],
#  [{'danceability': 0.719,
#    'energy': 0.725,
#    'key': 10,
#    'loudness': -10.265,
#    'mode': 0,
#    'speechiness': 0.0575,
#    'acousticness': 0.927,
#    'instrumentalness': 0.00038,
#    'liveness': 0.142,
#    'valence': 0.602,
#    'tempo': 93.999,
#    'type': 'audio_features',
#    'id': '7qiOAvr4gA9iLcliY2i3wt',
#    'uri': 'spotify:track:7qiOAvr4gA9iLcliY2i3wt',
#    'track_href': 'https://api.spotify.com/v1/tracks/7qiOAvr4gA9iLcliY2i3wt',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7qiOAvr4gA9iLcliY2i3wt',
#    'duration_ms': 154427,
#    'time_signature': 4}],
#  [{'danceability': 0.476,
#    'energy': 0.227,
#    'key': 10,
#    'loudness': -13.947,
#    'mode': 1,
#    'speechiness': 0.0389,
#    'acousticness': 0.666,
#    'instrumentalness': 0.000397,
#    'liveness': 0.115,
#    'valence': 0.651,
#    'tempo': 164.179,
#    'type': 'audio_features',
#    'id': '2tT6mzIeQG2tAFIMTwR6DV',
#    'uri': 'spotify:track:2tT6mzIeQG2tAFIMTwR6DV',
#    'track_href': 'https://api.spotify.com/v1/tracks/2tT6mzIeQG2tAFIMTwR6DV',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2tT6mzIeQG2tAFIMTwR6DV',
#    'duration_ms': 143600,
#    'time_signature': 3}],
#  [{'danceability': 0.534,
#    'energy': 0.769,
#    'key': 1,
#    'loudness': -7.22,
#    'mode': 0,
#    'speechiness': 0.137,
#    'acousticness': 0.00312,
#    'instrumentalness': 0.0529,
#    'liveness': 0.277,
#    'valence': 0.825,
#    'tempo': 140.921,
#    'type': 'audio_features',
#    'id': '3PkONrBLObUSL75fcsEpXE',
#    'uri': 'spotify:track:3PkONrBLObUSL75fcsEpXE',
#    'track_href': 'https://api.spotify.com/v1/tracks/3PkONrBLObUSL75fcsEpXE',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3PkONrBLObUSL75fcsEpXE',
#    'duration_ms': 211747,
#    'time_signature': 4}],
#  [{'danceability': 0.522,
#    'energy': 0.875,
#    'key': 7,
#    'loudness': -8.315,
#    'mode': 1,
#    'speechiness': 0.125,
#    'acousticness': 0.8,
#    'instrumentalness': 0.0115,
#    'liveness': 0.365,
#    'valence': 0.588,
#    'tempo': 98.365,
#    'type': 'audio_features',
#    'id': '5eWabdYf3t4Zh5oWEWgDif',
#    'uri': 'spotify:track:5eWabdYf3t4Zh5oWEWgDif',
#    'track_href': 'https://api.spotify.com/v1/tracks/5eWabdYf3t4Zh5oWEWgDif',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5eWabdYf3t4Zh5oWEWgDif',
#    'duration_ms': 286733,
#    'time_signature': 4}],
#  [{'danceability': 0.514,
#    'energy': 0.574,
#    'key': 9,
#    'loudness': -7.224,
#    'mode': 1,
#    'speechiness': 0.0467,
#    'acousticness': 0.0443,
#    'instrumentalness': 0.00826,
#    'liveness': 0.142,
#    'valence': 0.369,
#    'tempo': 125.389,
#    'type': 'audio_features',
#    'id': '1ynkDh7e8WW1f208nPkzO4',
#    'uri': 'spotify:track:1ynkDh7e8WW1f208nPkzO4',
#    'track_href': 'https://api.spotify.com/v1/tracks/1ynkDh7e8WW1f208nPkzO4',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1ynkDh7e8WW1f208nPkzO4',
#    'duration_ms': 177520,
#    'time_signature': 4}],
#  [{'danceability': 0.734,
#    'energy': 0.866,
#    'key': 2,
#    'loudness': -4.182,
#    'mode': 1,
#    'speechiness': 0.0719,
#    'acousticness': 0.023,
#    'instrumentalness': 3.07e-06,
#    'liveness': 0.116,
#    'valence': 0.671,
#    'tempo': 103.021,
#    'type': 'audio_features',
#    'id': '0JMpDDmRJnSjQDMS68TVGx',
#    'uri': 'spotify:track:0JMpDDmRJnSjQDMS68TVGx',
#    'track_href': 'https://api.spotify.com/v1/tracks/0JMpDDmRJnSjQDMS68TVGx',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/0JMpDDmRJnSjQDMS68TVGx',
#    'duration_ms': 349333,
#    'time_signature': 4}],
#  [{'danceability': 0.585,
#    'energy': 0.59,
#    'key': 11,
#    'loudness': -9.142,
#    'mode': 0,
#    'speechiness': 0.0516,
#    'acousticness': 0.161,
#    'instrumentalness': 2.12e-06,
#    'liveness': 0.0943,
#    'valence': 0.656,
#    'tempo': 131.027,
#    'type': 'audio_features',
#    'id': '5gzLGvHDeVbCy7xBcbV38e',
#    'uri': 'spotify:track:5gzLGvHDeVbCy7xBcbV38e',
#    'track_href': 'https://api.spotify.com/v1/tracks/5gzLGvHDeVbCy7xBcbV38e',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5gzLGvHDeVbCy7xBcbV38e',
#    'duration_ms': 336600,
#    'time_signature': 1}],
#  [{'danceability': 0.772,
#    'energy': 0.861,
#    'key': 7,
#    'loudness': -2.389,
#    'mode': 1,
#    'speechiness': 0.0898,
#    'acousticness': 0.135,
#    'instrumentalness': 0.000742,
#    'liveness': 0.064,
#    'valence': 0.424,
#    'tempo': 133.918,
#    'type': 'audio_features',
#    'id': '3tkbjyAmQnGsD52Rn8TCX8',
#    'uri': 'spotify:track:3tkbjyAmQnGsD52Rn8TCX8',
#    'track_href': 'https://api.spotify.com/v1/tracks/3tkbjyAmQnGsD52Rn8TCX8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3tkbjyAmQnGsD52Rn8TCX8',
#    'duration_ms': 204160,
#    'time_signature': 4}],
#  [{'danceability': 0.563,
#    'energy': 0.939,
#    'key': 2,
#    'loudness': -2.698,
#    'mode': 1,
#    'speechiness': 0.0345,
#    'acousticness': 0.0254,
#    'instrumentalness': 0.234,
#    'liveness': 0.331,
#    'valence': 0.79,
#    'tempo': 92.495,
#    'type': 'audio_features',
#    'id': '4yT2bpxig5pusTJHhtaRp8',
#    'uri': 'spotify:track:4yT2bpxig5pusTJHhtaRp8',
#    'track_href': 'https://api.spotify.com/v1/tracks/4yT2bpxig5pusTJHhtaRp8',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4yT2bpxig5pusTJHhtaRp8',
#    'duration_ms': 209253,
#    'time_signature': 4}],
#  [{'danceability': 0.687,
#    'energy': 0.352,
#    'key': 8,
#    'loudness': -9.814,
#    'mode': 0,
#    'speechiness': 0.495,
#    'acousticness': 0.618,
#    'instrumentalness': 0,
#    'liveness': 0.0505,
#    'valence': 0.88,
#    'tempo': 143.973,
#    'type': 'audio_features',
#    'id': '2770ENe7M1xvMkPDBuSwaY',
#    'uri': 'spotify:track:2770ENe7M1xvMkPDBuSwaY',
#    'track_href': 'https://api.spotify.com/v1/tracks/2770ENe7M1xvMkPDBuSwaY',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2770ENe7M1xvMkPDBuSwaY',
#    'duration_ms': 131507,
#    'time_signature': 3}],
#  [{'danceability': 0.704,
#    'energy': 0.277,
#    'key': 1,
#    'loudness': -8.544,
#    'mode': 1,
#    'speechiness': 0.0364,
#    'acousticness': 0.611,
#    'instrumentalness': 0,
#    'liveness': 0.119,
#    'valence': 0.623,
#    'tempo': 71.077,
#    'type': 'audio_features',
#    'id': '6s9LdsJMuAvbGFSqtKNpdZ',
#    'uri': 'spotify:track:6s9LdsJMuAvbGFSqtKNpdZ',
#    'track_href': 'https://api.spotify.com/v1/tracks/6s9LdsJMuAvbGFSqtKNpdZ',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6s9LdsJMuAvbGFSqtKNpdZ',
#    'duration_ms': 153067,
#    'time_signature': 4}],
#  [{'danceability': 0.553,
#    'energy': 0.0759,
#    'key': 2,
#    'loudness': -18.051,
#    'mode': 0,
#    'speechiness': 0.0349,
#    'acousticness': 0.51,
#    'instrumentalness': 0.000446,
#    'liveness': 0.116,
#    'valence': 0.16,
#    'tempo': 133.508,
#    'type': 'audio_features',
#    'id': '7pMPA9uyznFQQK4g2wwewF',
#    'uri': 'spotify:track:7pMPA9uyznFQQK4g2wwewF',
#    'track_href': 'https://api.spotify.com/v1/tracks/7pMPA9uyznFQQK4g2wwewF',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7pMPA9uyznFQQK4g2wwewF',
#    'duration_ms': 251933,
#    'time_signature': 4}],
#  [{'danceability': 0.527,
#    'energy': 0.282,
#    'key': 0,
#    'loudness': -12.428,
#    'mode': 1,
#    'speechiness': 0.0355,
#    'acousticness': 0.868,
#    'instrumentalness': 0,
#    'liveness': 0.159,
#    'valence': 0.769,
#    'tempo': 145.219,
#    'type': 'audio_features',
#    'id': '5NqojE0k28VhuA5J3IGCvO',
#    'uri': 'spotify:track:5NqojE0k28VhuA5J3IGCvO',
#    'track_href': 'https://api.spotify.com/v1/tracks/5NqojE0k28VhuA5J3IGCvO',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/5NqojE0k28VhuA5J3IGCvO',
#    'duration_ms': 232026,
#    'time_signature': 3}],
#  [{'danceability': 0.661,
#    'energy': 0.635,
#    'key': 9,
#    'loudness': -7.02,
#    'mode': 1,
#    'speechiness': 0.0626,
#    'acousticness': 0.025,
#    'instrumentalness': 0,
#    'liveness': 0.172,
#    'valence': 0.633,
#    'tempo': 74.991,
#    'type': 'audio_features',
#    'id': '3wXcRlQqH8ppCcvpBA6Bdv',
#    'uri': 'spotify:track:3wXcRlQqH8ppCcvpBA6Bdv',
#    'track_href': 'https://api.spotify.com/v1/tracks/3wXcRlQqH8ppCcvpBA6Bdv',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/3wXcRlQqH8ppCcvpBA6Bdv',
#    'duration_ms': 238287,
#    'time_signature': 4}],
#  [{'danceability': 0.539,
#    'energy': 0.846,
#    'key': 10,
#    'loudness': -6.739,
#    'mode': 0,
#    'speechiness': 0.0376,
#    'acousticness': 0.11,
#    'instrumentalness': 3.9e-05,
#    'liveness': 0.11,
#    'valence': 0.668,
#    'tempo': 100.002,
#    'type': 'audio_features',
#    'id': '6J8SONJwAIizCJm0QhEi4Y',
#    'uri': 'spotify:track:6J8SONJwAIizCJm0QhEi4Y',
#    'track_href': 'https://api.spotify.com/v1/tracks/6J8SONJwAIizCJm0QhEi4Y',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6J8SONJwAIizCJm0QhEi4Y',
#    'duration_ms': 179635,
#    'time_signature': 4}],
#  [{'danceability': 0.821,
#    'energy': 0.676,
#    'key': 3,
#    'loudness': -6.366,
#    'mode': 0,
#    'speechiness': 0.0547,
#    'acousticness': 0.187,
#    'instrumentalness': 0.0001,
#    'liveness': 0.0904,
#    'valence': 0.559,
#    'tempo': 119.012,
#    'type': 'audio_features',
#    'id': '1FBeSZBuAZvnF8eCbixeNs',
#    'uri': 'spotify:track:1FBeSZBuAZvnF8eCbixeNs',
#    'track_href': 'https://api.spotify.com/v1/tracks/1FBeSZBuAZvnF8eCbixeNs',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1FBeSZBuAZvnF8eCbixeNs',
#    'duration_ms': 213187,
#    'time_signature': 4}],
#  [{'danceability': 0.746,
#    'energy': 0.735,
#    'key': 10,
#    'loudness': -7.15,
#    'mode': 0,
#    'speechiness': 0.0523,
#    'acousticness': 0.0323,
#    'instrumentalness': 0.012,
#    'liveness': 0.141,
#    'valence': 0.602,
#    'tempo': 107.004,
#    'type': 'audio_features',
#    'id': '1wbBJEwfyiMBylevZKI1lr',
#    'uri': 'spotify:track:1wbBJEwfyiMBylevZKI1lr',
#    'track_href': 'https://api.spotify.com/v1/tracks/1wbBJEwfyiMBylevZKI1lr',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/1wbBJEwfyiMBylevZKI1lr',
#    'duration_ms': 224373,
#    'time_signature': 4}],
#  [{'danceability': 0.847,
#    'energy': 0.273,
#    'key': 0,
#    'loudness': -14.58,
#    'mode': 1,
#    'speechiness': 0.08,
#    'acousticness': 0.323,
#    'instrumentalness': 0.00286,
#    'liveness': 0.0629,
#    'valence': 0.672,
#    'tempo': 133.673,
#    'type': 'audio_features',
#    'id': '2Drwe6HvPVZbKMS21MvkMN',
#    'uri': 'spotify:track:2Drwe6HvPVZbKMS21MvkMN',
#    'track_href': 'https://api.spotify.com/v1/tracks/2Drwe6HvPVZbKMS21MvkMN',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2Drwe6HvPVZbKMS21MvkMN',
#    'duration_ms': 263573,
#    'time_signature': 4}],
#  [{'danceability': 0.557,
#    'energy': 0.261,
#    'key': 7,
#    'loudness': -10.515,
#    'mode': 1,
#    'speechiness': 0.0294,
#    'acousticness': 0.85,
#    'instrumentalness': 6.55e-06,
#    'liveness': 0.114,
#    'valence': 0.225,
#    'tempo': 85.972,
#    'type': 'audio_features',
#    'id': '7ykT8pkmQFUqXVmeyHqneM',
#    'uri': 'spotify:track:7ykT8pkmQFUqXVmeyHqneM',
#    'track_href': 'https://api.spotify.com/v1/tracks/7ykT8pkmQFUqXVmeyHqneM',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/7ykT8pkmQFUqXVmeyHqneM',
#    'duration_ms': 119227,
#    'time_signature': 4}],
#  [{'danceability': 0.714,
#    'energy': 0.479,
#    'key': 10,
#    'loudness': -10.825,
#    'mode': 0,
#    'speechiness': 0.0493,
#    'acousticness': 0.0558,
#    'instrumentalness': 1.29e-05,
#    'liveness': 0.119,
#    'valence': 0.567,
#    'tempo': 159.951,
#    'type': 'audio_features',
#    'id': '2OlZIjqZIRgWU17CyUUHzI',
#    'uri': 'spotify:track:2OlZIjqZIRgWU17CyUUHzI',
#    'track_href': 'https://api.spotify.com/v1/tracks/2OlZIjqZIRgWU17CyUUHzI',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2OlZIjqZIRgWU17CyUUHzI',
#    'duration_ms': 221307,
#    'time_signature': 4}],
#  [{'danceability': 0.346,
#    'energy': 0.583,
#    'key': 7,
#    'loudness': -8.776,
#    'mode': 1,
#    'speechiness': 0.0274,
#    'acousticness': 0.456,
#    'instrumentalness': 1.11e-06,
#    'liveness': 0.0988,
#    'valence': 0.686,
#    'tempo': 97.864,
#    'type': 'audio_features',
#    'id': '6GQQz48swxNlRrhflWmd2q',
#    'uri': 'spotify:track:6GQQz48swxNlRrhflWmd2q',
#    'track_href': 'https://api.spotify.com/v1/tracks/6GQQz48swxNlRrhflWmd2q',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/6GQQz48swxNlRrhflWmd2q',
#    'duration_ms': 249745,
#    'time_signature': 4}],
#  [{'danceability': 0.404,
#    'energy': 0.835,
#    'key': 6,
#    'loudness': -5.199,
#    'mode': 1,
#    'speechiness': 0.0753,
#    'acousticness': 9.17e-05,
#    'instrumentalness': 0.00409,
#    'liveness': 0.223,
#    'valence': 0.341,
#    'tempo': 135.946,
#    'type': 'audio_features',
#    'id': '4RGxYRGTYahTxrSe0r0Hi0',
#    'uri': 'spotify:track:4RGxYRGTYahTxrSe0r0Hi0',
#    'track_href': 'https://api.spotify.com/v1/tracks/4RGxYRGTYahTxrSe0r0Hi0',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/4RGxYRGTYahTxrSe0r0Hi0',
#    'duration_ms': 201267,
#    'time_signature': 4}],
#  [{'danceability': 0.716,
#    'energy': 0.411,
#    'key': 7,
#    'loudness': -14.308,
#    'mode': 1,
#    'speechiness': 0.0465,
#    'acousticness': 0.27,
#    'instrumentalness': 0,
#    'liveness': 0.132,
#    'valence': 0.897,
#    'tempo': 95.022,
#    'type': 'audio_features',
#    'id': '2lEf6XmMxXMjHZQnoG3O8S',
#    'uri': 'spotify:track:2lEf6XmMxXMjHZQnoG3O8S',
#    'track_href': 'https://api.spotify.com/v1/tracks/2lEf6XmMxXMjHZQnoG3O8S',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2lEf6XmMxXMjHZQnoG3O8S',
#    'duration_ms': 202067,
#    'time_signature': 4}],
#  [{'danceability': 0.475,
#    'energy': 0.325,
#    'key': 0,
#    'loudness': -11.789,
#    'mode': 1,
#    'speechiness': 0.0267,
#    'acousticness': 0.522,
#    'instrumentalness': 0.00782,
#    'liveness': 0.0766,
#    'valence': 0.149,
#    'tempo': 82.546,
#    'type': 'audio_features',
#    'id': '13xsVynFoITPoyvWz9xMRb',
#    'uri': 'spotify:track:13xsVynFoITPoyvWz9xMRb',
#    'track_href': 'https://api.spotify.com/v1/tracks/13xsVynFoITPoyvWz9xMRb',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/13xsVynFoITPoyvWz9xMRb',
#    'duration_ms': 232661,
#    'time_signature': 4}],
#  [{'danceability': 0.581,
#    'energy': 0.325,
#    'key': 0,
#    'loudness': -14.107,
#    'mode': 1,
#    'speechiness': 0.0335,
#    'acousticness': 0.141,
#    'instrumentalness': 0.658,
#    'liveness': 0.104,
#    'valence': 0.0598,
#    'tempo': 130.06,
#    'type': 'audio_features',
#    'id': '2JS1WiTlHkIZv4rOqu2eLn',
#    'uri': 'spotify:track:2JS1WiTlHkIZv4rOqu2eLn',
#    'track_href': 'https://api.spotify.com/v1/tracks/2JS1WiTlHkIZv4rOqu2eLn',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2JS1WiTlHkIZv4rOqu2eLn',
#    'duration_ms': 272733,
#    'time_signature': 4}],
#  [{'danceability': 0.5,
#    'energy': 0.703,
#    'key': 8,
#    'loudness': -12.605,
#    'mode': 1,
#    'speechiness': 0.0315,
#    'acousticness': 0.118,
#    'instrumentalness': 0.0345,
#    'liveness': 0.265,
#    'valence': 0.979,
#    'tempo': 149.34,
#    'type': 'audio_features',
#    'id': '2AMaRELgVNjnyLtoPchdO6',
#    'uri': 'spotify:track:2AMaRELgVNjnyLtoPchdO6',
#    'track_href': 'https://api.spotify.com/v1/tracks/2AMaRELgVNjnyLtoPchdO6',
#    'analysis_url': 'https://api.spotify.com/v1/audio-analysis/2AMaRELgVNjnyLtoPchdO6',
#    'duration_ms': 149107,
#    'time_signature': 4}],
#  ...]

# %%
audio_features_df = pd.DataFrame(audio_features)

# %%
audio_features_df
# Out:
#                                                       0
# 0     {'danceability': 0.823, 'energy': 0.671, 'key'...
# 1     {'danceability': 0.375, 'energy': 0.606, 'key'...
# 2     {'danceability': 0.738, 'energy': 0.491, 'key'...
# 3     {'danceability': 0.657, 'energy': 0.488, 'key'...
# 4     {'danceability': 0.753, 'energy': 0.594, 'key'...
# ...                                                 ...
# 9995  {'danceability': 0.824, 'energy': 0.376, 'key'...
# 9996  {'danceability': 0.673, 'energy': 0.568, 'key'...
# 9997  {'danceability': 0.684, 'energy': 0.504, 'key'...
# 9998  {'danceability': 0.677, 'energy': 0.41, 'key':...
# 9999  {'danceability': 0.638, 'energy': 0.464, 'key'...
#
# [10000 rows x 1 columns]

# %%
import pandas as pd
from pandas import json_normalize

audio_features_df1 = json_normalize(audio_features_df[0])

# %%
audio_features_df1
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.823   0.671   11    -6.437     1       0.0592       0.55100
# 1            0.375   0.606    4    -9.383     0       0.1970       0.33900
# 2            0.738   0.491    6   -13.407     0       0.0487       0.29800
# 3            0.657   0.488    8   -10.416     0       0.0456       0.21300
# 4            0.753   0.594    1    -9.486     0       0.0816       0.07110
# ...            ...     ...  ...       ...   ...          ...           ...
# 9995         0.824   0.376    3   -11.921     1       0.2200       0.70500
# 9996         0.673   0.568    9    -6.708     0       0.2390       0.50100
# 9997         0.684   0.504    9    -8.913     1       0.0801       0.09720
# 9998         0.677   0.410    9   -10.598     0       0.0400       0.59100
# 9999         0.638   0.464    5    -9.092     1       0.0240       0.00871
#
#       instrumentalness  liveness  valence    tempo            type  \
# 0             0.001440    0.3540    0.662  125.052  audio_features
# 1             0.000924    0.4240    0.883   91.564  audio_features
# 2             0.218000    0.1190    0.809  126.960  audio_features
# 3             0.094200    0.3600    0.662  149.763  audio_features
# 4             0.000000    0.3910    0.562  112.568  audio_features
# ...                ...       ...      ...      ...             ...
# 9995          0.011500    0.1060    0.819   94.013  audio_features
# 9996          0.000881    0.1390    0.568  170.131  audio_features
# 9997          0.000290    0.3360    0.740   86.226  audio_features
# 9998          0.103000    0.0813    0.515   81.924  audio_features
# 9999          0.000068    0.1200    0.279   81.075  audio_features
#
#                           id                                   uri  \
# 0     6uDlwsguxFDgbakvPyhChp  spotify:track:6uDlwsguxFDgbakvPyhChp
# 1     00LvjMnpznr4MZFSA8x9sA  spotify:track:00LvjMnpznr4MZFSA8x9sA
# 2     3E8gEvhLia6w9lQv3hfxzM  spotify:track:3E8gEvhLia6w9lQv3hfxzM
# 3     2jjPlj6KFzCffJ7KVQMwHX  spotify:track:2jjPlj6KFzCffJ7KVQMwHX
# 4     3seHx466iTcUmWE9dOVB3v  spotify:track:3seHx466iTcUmWE9dOVB3v
# ...                      ...                                   ...
# 9995  57BxU4uqdbl6TITWtnQDMw  spotify:track:57BxU4uqdbl6TITWtnQDMw
# 9996  7lL6ND4Jj1tWpoDFaJoxtS  spotify:track:7lL6ND4Jj1tWpoDFaJoxtS
# 9997  1PNaGC2ihDmVCldSce119E  spotify:track:1PNaGC2ihDmVCldSce119E
# 9998  2887tlqmjY4WcyQ3Dy6dZy  spotify:track:2887tlqmjY4WcyQ3Dy6dZy
# 9999  5xPYheD4STE2K5o6ff9WJK  spotify:track:5xPYheD4STE2K5o6ff9WJK
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6uDlwsguxFDg...
# 1     https://api.spotify.com/v1/tracks/00LvjMnpznr4...
# 2     https://api.spotify.com/v1/tracks/3E8gEvhLia6w...
# 3     https://api.spotify.com/v1/tracks/2jjPlj6KFzCf...
# 4     https://api.spotify.com/v1/tracks/3seHx466iTcU...
# ...                                                 ...
# 9995  https://api.spotify.com/v1/tracks/57BxU4uqdbl6...
# 9996  https://api.spotify.com/v1/tracks/7lL6ND4Jj1tW...
# 9997  https://api.spotify.com/v1/tracks/1PNaGC2ihDmV...
# 9998  https://api.spotify.com/v1/tracks/2887tlqmjY4W...
# 9999  https://api.spotify.com/v1/tracks/5xPYheD4STE2...
#
#                                            analysis_url  duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6uDl...       188697
# 1     https://api.spotify.com/v1/audio-analysis/00Lv...        51373
# 2     https://api.spotify.com/v1/audio-analysis/3E8g...       221533
# 3     https://api.spotify.com/v1/audio-analysis/2jjP...       216235
# 4     https://api.spotify.com/v1/audio-analysis/3seH...       193093
# ...                                                 ...          ...
# 9995  https://api.spotify.com/v1/audio-analysis/57Bx...       324608
# 9996  https://api.spotify.com/v1/audio-analysis/7lL6...       143533
# 9997  https://api.spotify.com/v1/audio-analysis/1PNa...       216601
# 9998  https://api.spotify.com/v1/audio-analysis/2887...       274013
# 9999  https://api.spotify.com/v1/audio-analysis/5xPY...       146467
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 9995               4
# 9996               4
# 9997               4
# 9998               4
# 9999               4
#
# [10000 rows x 18 columns]

# %%
df_final = pd.concat([playlist_df, audio_features_df1], axis=1)

# %%
df_final
# Out:
#                                            name              artist  \
# 0          This Magic Moment - Crisp.nl Version        MassiveMusic
# 1                                         00h00              Hoosky
# 2                                Under My Thumb  The Rolling Stones
# 3                                    Conquer Me              Jane B
# 4                 Dapper (feat. Anderson .Paak)        Domo Genesis
# ...                                         ...                 ...
# 9995                                      Lijay      Mulatu Astatke
# 9996  Pretty Nice Life (feat. Tiken Jah Fakoly)            M.I.L.K.
# 9997             Take It Slow - Mousse T. Remix        Boozoo Bajou
# 9998                         Birds of a Feather               Mocky
# 9999                             Freeway (2006)         Earl Elliot
#
#                                        uri  danceability  energy  key  \
# 0     spotify:track:6uDlwsguxFDgbakvPyhChp         0.823   0.671   11
# 1     spotify:track:00LvjMnpznr4MZFSA8x9sA         0.375   0.606    4
# 2     spotify:track:3E8gEvhLia6w9lQv3hfxzM         0.738   0.491    6
# 3     spotify:track:2jjPlj6KFzCffJ7KVQMwHX         0.657   0.488    8
# 4     spotify:track:3seHx466iTcUmWE9dOVB3v         0.753   0.594    1
# ...                                    ...           ...     ...  ...
# 9995  spotify:track:57BxU4uqdbl6TITWtnQDMw         0.824   0.376    3
# 9996  spotify:track:7lL6ND4Jj1tWpoDFaJoxtS         0.673   0.568    9
# 9997  spotify:track:1PNaGC2ihDmVCldSce119E         0.684   0.504    9
# 9998  spotify:track:2887tlqmjY4WcyQ3Dy6dZy         0.677   0.410    9
# 9999  spotify:track:5xPYheD4STE2K5o6ff9WJK         0.638   0.464    5
#
#       loudness  mode  speechiness  acousticness  ...  liveness  valence  \
# 0       -6.437     1       0.0592       0.55100  ...    0.3540    0.662
# 1       -9.383     0       0.1970       0.33900  ...    0.4240    0.883
# 2      -13.407     0       0.0487       0.29800  ...    0.1190    0.809
# 3      -10.416     0       0.0456       0.21300  ...    0.3600    0.662
# 4       -9.486     0       0.0816       0.07110  ...    0.3910    0.562
# ...        ...   ...          ...           ...  ...       ...      ...
# 9995   -11.921     1       0.2200       0.70500  ...    0.1060    0.819
# 9996    -6.708     0       0.2390       0.50100  ...    0.1390    0.568
# 9997    -8.913     1       0.0801       0.09720  ...    0.3360    0.740
# 9998   -10.598     0       0.0400       0.59100  ...    0.0813    0.515
# 9999    -9.092     1       0.0240       0.00871  ...    0.1200    0.279
#
#         tempo            type                      id  \
# 0     125.052  audio_features  6uDlwsguxFDgbakvPyhChp
# 1      91.564  audio_features  00LvjMnpznr4MZFSA8x9sA
# 2     126.960  audio_features  3E8gEvhLia6w9lQv3hfxzM
# 3     149.763  audio_features  2jjPlj6KFzCffJ7KVQMwHX
# 4     112.568  audio_features  3seHx466iTcUmWE9dOVB3v
# ...       ...             ...                     ...
# 9995   94.013  audio_features  57BxU4uqdbl6TITWtnQDMw
# 9996  170.131  audio_features  7lL6ND4Jj1tWpoDFaJoxtS
# 9997   86.226  audio_features  1PNaGC2ihDmVCldSce119E
# 9998   81.924  audio_features  2887tlqmjY4WcyQ3Dy6dZy
# 9999   81.075  audio_features  5xPYheD4STE2K5o6ff9WJK
#
#                                        uri  \
# 0     spotify:track:6uDlwsguxFDgbakvPyhChp
# 1     spotify:track:00LvjMnpznr4MZFSA8x9sA
# 2     spotify:track:3E8gEvhLia6w9lQv3hfxzM
# 3     spotify:track:2jjPlj6KFzCffJ7KVQMwHX
# 4     spotify:track:3seHx466iTcUmWE9dOVB3v
# ...                                    ...
# 9995  spotify:track:57BxU4uqdbl6TITWtnQDMw
# 9996  spotify:track:7lL6ND4Jj1tWpoDFaJoxtS
# 9997  spotify:track:1PNaGC2ihDmVCldSce119E
# 9998  spotify:track:2887tlqmjY4WcyQ3Dy6dZy
# 9999  spotify:track:5xPYheD4STE2K5o6ff9WJK
#
#                                              track_href  \
# 0     https://api.spotify.com/v1/tracks/6uDlwsguxFDg...
# 1     https://api.spotify.com/v1/tracks/00LvjMnpznr4...
# 2     https://api.spotify.com/v1/tracks/3E8gEvhLia6w...
# 3     https://api.spotify.com/v1/tracks/2jjPlj6KFzCf...
# 4     https://api.spotify.com/v1/tracks/3seHx466iTcU...
# ...                                                 ...
# 9995  https://api.spotify.com/v1/tracks/57BxU4uqdbl6...
# 9996  https://api.spotify.com/v1/tracks/7lL6ND4Jj1tW...
# 9997  https://api.spotify.com/v1/tracks/1PNaGC2ihDmV...
# 9998  https://api.spotify.com/v1/tracks/2887tlqmjY4W...
# 9999  https://api.spotify.com/v1/tracks/5xPYheD4STE2...
#
#                                            analysis_url duration_ms  \
# 0     https://api.spotify.com/v1/audio-analysis/6uDl...      188697
# 1     https://api.spotify.com/v1/audio-analysis/00Lv...       51373
# 2     https://api.spotify.com/v1/audio-analysis/3E8g...      221533
# 3     https://api.spotify.com/v1/audio-analysis/2jjP...      216235
# 4     https://api.spotify.com/v1/audio-analysis/3seH...      193093
# ...                                                 ...         ...
# 9995  https://api.spotify.com/v1/audio-analysis/57Bx...      324608
# 9996  https://api.spotify.com/v1/audio-analysis/7lL6...      143533
# 9997  https://api.spotify.com/v1/audio-analysis/1PNa...      216601
# 9998  https://api.spotify.com/v1/audio-analysis/2887...      274013
# 9999  https://api.spotify.com/v1/audio-analysis/5xPY...      146467
#
#       time_signature
# 0                  4
# 1                  4
# 2                  4
# 3                  4
# 4                  4
# ...              ...
# 9995               4
# 9996               4
# 9997               4
# 9998               4
# 9999               4
#
# [10000 rows x 21 columns]

# %%
df_final.to_csv('my_playlist.csv', index=False)
